# %%
import os
import json
import numpy as np
import torch
import torch.nn as nn
from torch.optim.lr_scheduler import ReduceLROnPlateau
from torch.utils.data import Dataset, DataLoader
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from scipy.interpolate import interp1d
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import f1_score, confusion_matrix

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %%
# 랜드마크 인덱스 정의
LANDMARKS = [0, 11, 12, 15, 16, 23, 24, 25, 26, 27, 28]

# 데이터 증강 함수 정의
def augment_sequence(sequence, factor=0.2):
    time_warped = []
    for landmark in sequence:
        x = np.arange(len(landmark))
        f = interp1d(x, landmark, kind='linear', axis=0)
        x_new = np.linspace(0, len(landmark) - 1, num=int(len(landmark) * (1 + factor)))
        time_warped.append(f(x_new))
    return np.array(time_warped)

# 데이터셋 클래스 정의
class FallSequenceDataset(Dataset):
    def __init__(self, json_files, sequence_length=3):
        self.sequence_length = sequence_length
        self.sequences = []
        self.labels = []
        self.scaler = StandardScaler()
        print(f"LANDMARKS length: {len(LANDMARKS)}")
    
        all_landmarks = []
        
        for json_file in json_files:
            print(f'Processing file: {json_file}')
            with open(json_file, 'r') as f:
                data = json.load(f)
            
            frames = list(data['pose_data'].values())
            
            for i in range(0, len(frames) - self.sequence_length + 1):
                sequence = frames[i:i+self.sequence_length]
                landmarks = []
                fall_frames = 0
                
                for frame in sequence:
                    frame_landmarks = []
                    for landmark in LANDMARKS:
                        frame_landmarks.extend([
                            frame[f'landmark_{landmark}']['x'],
                            frame[f'landmark_{landmark}']['y']
                        ])
                    landmarks.append(frame_landmarks)
                    if frame['class'] == 'Fall':
                        fall_frames += 1
                # 데이터 증강 적용        
                augmented_sequence = augment_sequence(landmarks)            
                all_landmarks.extend(augmented_sequence)
                
                # 레이블 재정의
                if fall_frames == 0:
                    label = 0  # 비낙상
                elif fall_frames == self.sequence_length:
                    label = 2  # 완전 낙상
                else:
                    label = 1  # 낙상 위험
                
                self.sequences.append(augmented_sequence)
                self.labels.append(label)
        
        # 전체 데이터 정규화
        all_landmarks = np.array(all_landmarks)
        all_landmarks_scaled = self.scaler.fit_transform(all_landmarks)
        
        # 정규화된 데이터를 다시 시퀀스로 재구성
        for i in range(len(self.sequences)):
            start = i * self.sequence_length
            end = start + self.sequence_length
            self.sequences[i] = all_landmarks_scaled[start:end]
        
        if self.sequences:
            print(f"Sample sequence shape: {self.sequences[0].shape}")
        else:
            print("No sequences were created.")

    def __len__(self):
        return len(self.sequences)

    def __getitem__(self, idx):
        if idx >= len(self.sequences):
            raise IndexError(f"Index {idx} out of range. Dataset length: {len(self.sequences)}")
        sequence = self.sequences[idx]
        return torch.FloatTensor(sequence), torch.LongTensor([self.labels[idx]]).squeeze()

# GRU 모델 정의
class FallDetectionGRU(nn.Module):
    def __init__(self, input_size, hidden_size=64, num_layers=2, output_size=3, dropout = 0.5):
        super(FallDetectionGRU, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.gru = nn.GRU(input_size, hidden_size, num_layers, batch_first=True, dropout = dropout)
        self.fc = nn.Linear(hidden_size, output_size)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(x.device)
        out, _ = self.gru(x, h0)
        out = self.dropout(out[ : , -1, :])
        out = self.fc(out)
        return out

# 데이터 로드 및 전처리
json_folder = 'D:\\human_fall\\re_landmark\\re_train_NY_json'
json_files = [os.path.join(json_folder, f) for f in os.listdir(json_folder) if f.endswith('.json')]
dataset = FallSequenceDataset(json_files)

# 데이터셋을 학습 및 검증 세트로 분할
train_indices, val_indices = train_test_split(range(len(dataset)), test_size=0.2)
train_dataset = torch.utils.data.Subset(dataset, train_indices)
val_dataset = torch.utils.data.Subset(dataset, val_indices)

# 데이터 로더 생성 전에 클래스 가중치 계산
class_weights = compute_class_weight('balanced', classes=np.unique(dataset.labels), y=dataset.labels)
class_weights = torch.FloatTensor(class_weights).to(device)

# 손실 함수에 가중치 적용
criterion = nn.CrossEntropyLoss(weight=class_weights)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=32)

if len(dataset) > 0:
    sample_sequence, sample_label = dataset[0]
    input_size = sample_sequence.shape[1]
    model = FallDetectionGRU(input_size).to(device)
else:
    print("데이터 없음")
    exit()

criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001,  weight_decay=1e-5)
scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=5, verbose=True)
num_epochs = 500
best_loss = float('inf')
patience = 50 # 15 이후 다시 실행을 위해 50으로 변경
no_improve = 0

for epoch in range(num_epochs):
    model.train()
    total_loss_train = 0
    
    for sequences, labels in train_loader:
        sequences, labels = sequences.to(device), labels.to(device)
        
        optimizer.zero_grad()
        outputs = model(sequences)
        loss_train = criterion(outputs, labels.view(-1))
        loss_train.backward()
        optimizer.step()
        
        total_loss_train += loss_train.item()
    
    avg_loss_train = total_loss_train / len(train_loader)

    # 검증 단계 추가
    model.eval()
    total_loss_val = 0
    
    with torch.no_grad():
        for sequences_val, labels_val in val_loader:
            sequences_val, labels_val = sequences_val.to(device), labels_val.to(device)
            outputs_val = model(sequences_val)
            loss_val = criterion(outputs_val, labels_val.view(-1))
            total_loss_val += loss_val.item()
    
    avg_loss_val = total_loss_val / len(val_loader)

    print(f'Epoch [{epoch+1}/{num_epochs}], Train Loss: {avg_loss_train:.4f}, Val Loss: {avg_loss_val:.4f}')
    scheduler.step(avg_loss_val)
    
    if avg_loss_val < best_loss:
        best_loss = avg_loss_val
        no_improve = 0
        torch.save(model.state_dict(), 'try_2.pt')
    else:
        no_improve += 1
    
    if no_improve >= patience:
        print("Early stopping")
        break
    
def calculate_metrics(model, data_loader):
    model.eval()
    all_preds = []
    all_labels = []
    with torch.no_grad():
        for sequences, labels in data_loader:
            sequences, labels = sequences.to(device), labels.to(device)
            outputs = model(sequences)
            _, preds = torch.max(outputs, 1)
            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())
    
    f1 = f1_score(all_labels, all_preds, average='weighted')
    cm = confusion_matrix(all_labels, all_preds)
    return f1, cm

# 학습 루프 내에서 성능 지표 계산
train_f1, train_cm = calculate_metrics(model, train_loader)
val_f1, val_cm = calculate_metrics(model, val_loader)
print(f'Train F1: {train_f1:.4f}, Val F1: {val_f1:.4f}')
print(f'Train CM:\n{train_cm}\nVal CM:\n{val_cm}')

print("Training completed")
# Out:
# LANDMARKS length: 11
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00060_H_A_SY_C1.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00060_H_A_SY_C2.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00060_H_A_SY_C3.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00060_H_A_SY_C4.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00060_H_A_SY_C5.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00060_H_A_SY_C6.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00060_H_A_SY_C7.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00060_H_A_SY_C8.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00093_H_A_FY_C1.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00093_H_A_FY_C2.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00093_H_A_FY_C3.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00093_H_A_FY_C4.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00093_H_A_FY_C5.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00093_H_A_FY_C6.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00093_H_A_FY_C7.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00093_H_A_FY_C8.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00096_H_A_FY_C1.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00096_H_A_FY_C2.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00096_H_A_FY_C3.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00096_H_A_FY_C4.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00096_H_A_FY_C5.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00096_H_A_FY_C6.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00096_H_A_FY_C7.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00096_H_A_FY_C8.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00108_H_A_SY_C1.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00108_H_A_SY_C2.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00108_H_A_SY_C3.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00108_H_A_SY_C4.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00108_H_A_SY_C5.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00108_H_A_SY_C6.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00108_H_A_SY_C7.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00108_H_A_SY_C8.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00112_H_A_SY_C1.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00112_H_A_SY_C2.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00112_H_A_SY_C3.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00112_H_A_SY_C4.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00112_H_A_SY_C5.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00112_H_A_SY_C6.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00112_H_A_SY_C7.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00112_H_A_SY_C8.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00114_H_A_BY_C1.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00114_H_A_BY_C2.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00114_H_A_BY_C3.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00114_H_A_BY_C4.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00114_H_A_BY_C5.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00114_H_A_BY_C6.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00114_H_A_BY_C7.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00114_H_A_BY_C8.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00121_H_A_N_C1.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00121_H_A_N_C2.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00121_H_A_N_C3.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00121_H_A_N_C4.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00121_H_A_N_C5.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00121_H_A_N_C6.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00121_H_A_N_C7.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00121_H_A_N_C8.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00130_H_A_FY_C1.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00130_H_A_FY_C2.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00130_H_A_FY_C3.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00130_H_A_FY_C4.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00130_H_A_FY_C5.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00130_H_A_FY_C6.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00130_H_A_FY_C7.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00130_H_A_FY_C8.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00132_H_A_BY_C1.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00132_H_A_BY_C2.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00132_H_A_BY_C3.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00132_H_A_BY_C4.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00132_H_A_BY_C5.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00132_H_A_BY_C6.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00132_H_A_BY_C7.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00132_H_A_BY_C8.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00158_H_A_SY_C1.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00158_H_A_SY_C2.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00158_H_A_SY_C3.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00158_H_A_SY_C4.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00158_H_A_SY_C5.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00158_H_A_SY_C6.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00158_H_A_SY_C7.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00158_H_A_SY_C8.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00164_H_A_N_C1.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00164_H_A_N_C2.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00164_H_A_N_C3.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00164_H_A_N_C4.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00164_H_A_N_C5.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00164_H_A_N_C6.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00164_H_A_N_C7.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00164_H_A_N_C8.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00171_H_A_BY_C1.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00171_H_A_BY_C2.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00171_H_A_BY_C3.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00171_H_A_BY_C4.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00171_H_A_BY_C5.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00171_H_A_BY_C6.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00171_H_A_BY_C7.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00171_H_A_BY_C8.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00172_H_A_N_C1.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00172_H_A_N_C2.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00172_H_A_N_C3.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00172_H_A_N_C4.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00172_H_A_N_C5.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00172_H_A_N_C6.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00172_H_A_N_C7.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00172_H_A_N_C8.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00174_H_A_SY_C1.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00174_H_A_SY_C2.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00174_H_A_SY_C3.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00174_H_A_SY_C4.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00174_H_A_SY_C5.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00174_H_A_SY_C6.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00174_H_A_SY_C7.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00174_H_A_SY_C8.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00175_H_A_BY_C1.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00175_H_A_BY_C2.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00175_H_A_BY_C3.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00175_H_A_BY_C4.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00175_H_A_BY_C5.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00175_H_A_BY_C6.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00175_H_A_BY_C7.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00175_H_A_BY_C8.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00188_H_A_N_C1.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00188_H_A_N_C2.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00188_H_A_N_C3.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00188_H_A_N_C4.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00188_H_A_N_C5.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00188_H_A_N_C6.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00188_H_A_N_C7.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00188_H_A_N_C8.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00191_H_A_BY_C1.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00191_H_A_BY_C2.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00191_H_A_BY_C3.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00191_H_A_BY_C4.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00191_H_A_BY_C5.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00191_H_A_BY_C6.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00191_H_A_BY_C7.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00191_H_A_BY_C8.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00193_H_A_FY_C1.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00193_H_A_FY_C2.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00193_H_A_FY_C3.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00193_H_A_FY_C4.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00193_H_A_FY_C5.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00193_H_A_FY_C6.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00193_H_A_FY_C7.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00193_H_A_FY_C8.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00194_H_A_SY_C1.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00194_H_A_SY_C2.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00194_H_A_SY_C3.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00194_H_A_SY_C4.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00194_H_A_SY_C5.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00194_H_A_SY_C6.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00194_H_A_SY_C7.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00194_H_A_SY_C8.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00247_H_D_BY_C1.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00247_H_D_BY_C2.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00247_H_D_BY_C3.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00247_H_D_BY_C4.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00247_H_D_BY_C5.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00247_H_D_BY_C6.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00247_H_D_BY_C7.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00247_H_D_BY_C8.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00258_H_D_SY_C1.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00258_H_D_SY_C2.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00258_H_D_SY_C3.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00258_H_D_SY_C4.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00258_H_D_SY_C5.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00258_H_D_SY_C6.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00258_H_D_SY_C7.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00258_H_D_SY_C8.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00265_H_D_FY_C1.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00265_H_D_FY_C2.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00265_H_D_FY_C3.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00265_H_D_FY_C4.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00265_H_D_FY_C5.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00265_H_D_FY_C6.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00265_H_D_FY_C7.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00265_H_D_FY_C8.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00269_H_D_FY_C1.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00269_H_D_FY_C2.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00269_H_D_FY_C3.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00269_H_D_FY_C4.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00269_H_D_FY_C5.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00269_H_D_FY_C6.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00269_H_D_FY_C7.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00269_H_D_FY_C8.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00291_H_A_BY_C1.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00291_H_A_BY_C2.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00291_H_A_BY_C3.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00291_H_A_BY_C4.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00291_H_A_BY_C5.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00291_H_A_BY_C6.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00291_H_A_BY_C7.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00291_H_A_BY_C8.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00299_H_A_BY_C1.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00299_H_A_BY_C2.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00299_H_A_BY_C3.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00299_H_A_BY_C4.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00299_H_A_BY_C5.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00299_H_A_BY_C6.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00299_H_A_BY_C7.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00299_H_A_BY_C8.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00302_H_A_BY_C1.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00302_H_A_BY_C2.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00302_H_A_BY_C3.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00302_H_A_BY_C4.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00302_H_A_BY_C5.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00302_H_A_BY_C6.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00302_H_A_BY_C7.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00302_H_A_BY_C8.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00323_H_A_FY_C1.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00323_H_A_FY_C2.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00323_H_A_FY_C3.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00323_H_A_FY_C4.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00323_H_A_FY_C5.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00323_H_A_FY_C6.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00323_H_A_FY_C7.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00323_H_A_FY_C8.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00341_H_A_SY_C1.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00341_H_A_SY_C2.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00341_H_A_SY_C3.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00341_H_A_SY_C4.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00341_H_A_SY_C5.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00341_H_A_SY_C6.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00341_H_A_SY_C7.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00341_H_A_SY_C8.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00478_H_A_BY_C1.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00478_H_A_BY_C2.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00478_H_A_BY_C3.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00478_H_A_BY_C4.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00478_H_A_BY_C5.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00478_H_A_BY_C6.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00478_H_A_BY_C7.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00478_H_A_BY_C8.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00480_H_A_BY_C1.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00480_H_A_BY_C2.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00480_H_A_BY_C3.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00480_H_A_BY_C4.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00480_H_A_BY_C5.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00480_H_A_BY_C6.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00480_H_A_BY_C7.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00480_H_A_BY_C8.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00486_H_D_N_C1.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00486_H_D_N_C2.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00486_H_D_N_C3.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00486_H_D_N_C4.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00486_H_D_N_C5.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00486_H_D_N_C6.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00486_H_D_N_C7.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00486_H_D_N_C8.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00505_H_D_FY_C1.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00505_H_D_FY_C2.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00505_H_D_FY_C3.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00505_H_D_FY_C4.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00505_H_D_FY_C5.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00505_H_D_FY_C6.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00505_H_D_FY_C7.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00505_H_D_FY_C8.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00526_H_D_FY_C1.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00526_H_D_FY_C2.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00526_H_D_FY_C3.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00526_H_D_FY_C4.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00526_H_D_FY_C5.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00526_H_D_FY_C6.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00526_H_D_FY_C7.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00526_H_D_FY_C8.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00533_H_D_N_C1.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00533_H_D_N_C2.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00533_H_D_N_C3.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00533_H_D_N_C4.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00533_H_D_N_C5.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00533_H_D_N_C6.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00533_H_D_N_C7.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00533_H_D_N_C8.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00548_H_D_FY_C1.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00548_H_D_FY_C2.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00548_H_D_FY_C3.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00548_H_D_FY_C4.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00548_H_D_FY_C5.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00548_H_D_FY_C6.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00548_H_D_FY_C7.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00548_H_D_FY_C8.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00574_H_D_FY_C1.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00574_H_D_FY_C2.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00574_H_D_FY_C3.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00574_H_D_FY_C4.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00574_H_D_FY_C5.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00574_H_D_FY_C6.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00574_H_D_FY_C7.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00574_H_D_FY_C8.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00593_H_D_BY_C1.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00593_H_D_BY_C2.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00593_H_D_BY_C3.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00593_H_D_BY_C4.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00593_H_D_BY_C5.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00593_H_D_BY_C6.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00593_H_D_BY_C7.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00593_H_D_BY_C8.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00596_H_D_FY_C1.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00596_H_D_FY_C2.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00596_H_D_FY_C3.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00596_H_D_FY_C4.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00596_H_D_FY_C5.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00596_H_D_FY_C6.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00596_H_D_FY_C7.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00596_H_D_FY_C8.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00615_H_D_SY_C1.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00615_H_D_SY_C2.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00615_H_D_SY_C3.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00615_H_D_SY_C4.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00615_H_D_SY_C5.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00615_H_D_SY_C6.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00615_H_D_SY_C7.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00615_H_D_SY_C8.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00619_H_D_FY_C1.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00619_H_D_FY_C2.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00619_H_D_FY_C3.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00619_H_D_FY_C4.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00619_H_D_FY_C5.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00619_H_D_FY_C6.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00619_H_D_FY_C7.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00619_H_D_FY_C8.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00665_H_D_FY_C1.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00665_H_D_FY_C2.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00665_H_D_FY_C3.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00665_H_D_FY_C4.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00665_H_D_FY_C5.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00665_H_D_FY_C6.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00665_H_D_FY_C7.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00665_H_D_FY_C8.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00676_H_D_SY_C1.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00676_H_D_SY_C2.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00676_H_D_SY_C3.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00676_H_D_SY_C4.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00676_H_D_SY_C5.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00676_H_D_SY_C6.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00676_H_D_SY_C7.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00676_H_D_SY_C8.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00690_H_D_N_C1.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00690_H_D_N_C2.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00690_H_D_N_C3.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00690_H_D_N_C4.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00690_H_D_N_C5.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00690_H_D_N_C6.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00690_H_D_N_C7.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00690_H_D_N_C8.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00704_H_D_FY_C1.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00704_H_D_FY_C2.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00704_H_D_FY_C3.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00704_H_D_FY_C4.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00704_H_D_FY_C5.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00704_H_D_FY_C6.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00704_H_D_FY_C7.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00704_H_D_FY_C8.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00705_H_D_BY_C1.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00705_H_D_BY_C2.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00705_H_D_BY_C3.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00705_H_D_BY_C4.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00705_H_D_BY_C5.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00705_H_D_BY_C6.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00705_H_D_BY_C7.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00705_H_D_BY_C8.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00707_H_D_BY_C1.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00707_H_D_BY_C2.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00707_H_D_BY_C3.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00707_H_D_BY_C4.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00707_H_D_BY_C5.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00707_H_D_BY_C6.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00707_H_D_BY_C7.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00707_H_D_BY_C8.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00712_H_D_BY_C1.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00712_H_D_BY_C2.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00712_H_D_BY_C3.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00712_H_D_BY_C4.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00712_H_D_BY_C5.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00712_H_D_BY_C6.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00712_H_D_BY_C7.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00712_H_D_BY_C8.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00737_H_D_BY_C1.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00737_H_D_BY_C2.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00737_H_D_BY_C3.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00737_H_D_BY_C4.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00737_H_D_BY_C5.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00737_H_D_BY_C6.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00737_H_D_BY_C7.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00737_H_D_BY_C8.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00751_O_E_N_C1.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00751_O_E_N_C2.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00751_O_E_N_C3.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00751_O_E_N_C4.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00751_O_E_N_C5.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00751_O_E_N_C6.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00751_O_E_N_C7.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00751_O_E_N_C8.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00758_O_E_N_C1.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00758_O_E_N_C2.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00758_O_E_N_C3.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00758_O_E_N_C4.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00758_O_E_N_C5.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00758_O_E_N_C6.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00758_O_E_N_C7.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00758_O_E_N_C8.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00777_O_E_N_C1.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00777_O_E_N_C2.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00777_O_E_N_C3.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00777_O_E_N_C4.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00777_O_E_N_C5.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00777_O_E_N_C6.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00777_O_E_N_C7.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00777_O_E_N_C8.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00788_O_E_N_C1.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00788_O_E_N_C2.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00788_O_E_N_C3.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00788_O_E_N_C4.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00788_O_E_N_C5.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00788_O_E_N_C6.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00788_O_E_N_C7.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00788_O_E_N_C8.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00792_O_E_N_C1.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00792_O_E_N_C2.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00792_O_E_N_C3.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00792_O_E_N_C4.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00792_O_E_N_C5.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00792_O_E_N_C6.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00792_O_E_N_C7.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00792_O_E_N_C8.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00799_O_E_N_C1.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00799_O_E_N_C2.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00799_O_E_N_C3.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00799_O_E_N_C4.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00799_O_E_N_C5.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00799_O_E_N_C6.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00799_O_E_N_C7.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00799_O_E_N_C8.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00815_O_E_BY_C1.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00815_O_E_BY_C2.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00815_O_E_BY_C3.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00815_O_E_BY_C4.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00815_O_E_BY_C5.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00815_O_E_BY_C6.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00815_O_E_BY_C7.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00815_O_E_BY_C8.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00864_O_E_FY_C1.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00864_O_E_FY_C2.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00864_O_E_FY_C3.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00864_O_E_FY_C4.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00864_O_E_FY_C5.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00864_O_E_FY_C6.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00864_O_E_FY_C7.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00864_O_E_FY_C8.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00867_O_E_FY_C1.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00867_O_E_FY_C2.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00867_O_E_FY_C3.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00867_O_E_FY_C4.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00867_O_E_FY_C5.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00867_O_E_FY_C6.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00867_O_E_FY_C7.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00867_O_E_FY_C8.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00879_O_E_FY_C1.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00879_O_E_FY_C2.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00879_O_E_FY_C3.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00879_O_E_FY_C4.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00879_O_E_FY_C5.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00879_O_E_FY_C6.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00879_O_E_FY_C7.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00879_O_E_FY_C8.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00888_O_E_N_C1.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00888_O_E_N_C2.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00888_O_E_N_C3.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00888_O_E_N_C4.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00888_O_E_N_C5.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00888_O_E_N_C6.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00888_O_E_N_C7.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00888_O_E_N_C8.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00896_O_E_FY_C1.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00896_O_E_FY_C2.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00896_O_E_FY_C3.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00896_O_E_FY_C4.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00896_O_E_FY_C5.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00896_O_E_FY_C6.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00896_O_E_FY_C7.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00896_O_E_FY_C8.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00902_O_E_FY_C1.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00902_O_E_FY_C2.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00902_O_E_FY_C3.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00902_O_E_FY_C4.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00902_O_E_FY_C5.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00902_O_E_FY_C6.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00902_O_E_FY_C7.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00902_O_E_FY_C8.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00945_O_E_FY_C1.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00945_O_E_FY_C2.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00945_O_E_FY_C3.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00945_O_E_FY_C4.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00945_O_E_FY_C5.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00945_O_E_FY_C6.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00945_O_E_FY_C7.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00945_O_E_FY_C8.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00969_O_E_BY_C1.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00969_O_E_BY_C2.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00969_O_E_BY_C3.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00969_O_E_BY_C4.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00969_O_E_BY_C5.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00969_O_E_BY_C6.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00969_O_E_BY_C7.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00969_O_E_BY_C8.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00983_O_E_N_C1.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00983_O_E_N_C2.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00983_O_E_N_C3.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00983_O_E_N_C4.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00983_O_E_N_C5.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00983_O_E_N_C6.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00983_O_E_N_C7.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00983_O_E_N_C8.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00998_O_E_FY_C1.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00998_O_E_FY_C2.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00998_O_E_FY_C3.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00998_O_E_FY_C4.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00998_O_E_FY_C5.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00998_O_E_FY_C6.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00998_O_E_FY_C7.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\00998_O_E_FY_C8.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\01006_O_E_FY_C1.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\01006_O_E_FY_C2.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\01006_O_E_FY_C3.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\01006_O_E_FY_C4.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\01006_O_E_FY_C5.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\01006_O_E_FY_C6.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\01006_O_E_FY_C7.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\01006_O_E_FY_C8.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\01054_O_E_N_C1.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\01054_O_E_N_C2.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\01054_O_E_N_C3.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\01054_O_E_N_C4.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\01054_O_E_N_C5.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\01054_O_E_N_C6.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\01054_O_E_N_C7.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\01054_O_E_N_C8.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\01089_O_E_N_C1.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\01089_O_E_N_C2.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\01089_O_E_N_C3.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\01089_O_E_N_C4.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\01089_O_E_N_C5.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\01089_O_E_N_C6.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\01089_O_E_N_C7.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\01089_O_E_N_C8.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\01112_O_E_N_C1.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\01112_O_E_N_C2.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\01112_O_E_N_C3.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\01112_O_E_N_C4.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\01112_O_E_N_C5.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\01112_O_E_N_C6.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\01112_O_E_N_C7.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\01112_O_E_N_C8.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\01128_O_E_N_C1.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\01128_O_E_N_C2.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\01128_O_E_N_C3.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\01128_O_E_N_C4.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\01128_O_E_N_C5.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\01128_O_E_N_C6.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\01128_O_E_N_C7.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\01128_O_E_N_C8.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\01130_O_E_BY_C1.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\01130_O_E_BY_C2.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\01130_O_E_BY_C3.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\01130_O_E_BY_C4.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\01130_O_E_BY_C5.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\01130_O_E_BY_C6.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\01130_O_E_BY_C7.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\01130_O_E_BY_C8.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\01135_O_E_N_C1.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\01135_O_E_N_C2.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\01135_O_E_N_C3.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\01135_O_E_N_C4.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\01135_O_E_N_C5.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\01135_O_E_N_C6.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\01135_O_E_N_C7.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\01135_O_E_N_C8.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\01148_O_E_N_C1.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\01148_O_E_N_C2.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\01148_O_E_N_C3.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\01148_O_E_N_C4.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\01148_O_E_N_C5.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\01148_O_E_N_C6.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\01148_O_E_N_C7.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\01148_O_E_N_C8.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\01162_O_E_N_C1.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\01162_O_E_N_C2.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\01162_O_E_N_C3.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\01162_O_E_N_C4.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\01162_O_E_N_C5.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\01162_O_E_N_C6.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\01162_O_E_N_C7.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\01162_O_E_N_C8.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\01164_O_E_FY_C1.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\01164_O_E_FY_C2.json
# ...
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\02813_H_D_FY_C4.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\02813_H_D_FY_C5.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\02813_H_D_FY_C6.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\02813_H_D_FY_C7.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\02813_H_D_FY_C8.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\02821_H_D_FY_C1.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\02821_H_D_FY_C2.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\02821_H_D_FY_C3.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\02821_H_D_FY_C4.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\02821_H_D_FY_C5.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\02821_H_D_FY_C6.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\02821_H_D_FY_C7.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\02821_H_D_FY_C8.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\02830_H_D_FY_C1.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\02830_H_D_FY_C2.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\02830_H_D_FY_C3.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\02830_H_D_FY_C4.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\02830_H_D_FY_C5.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\02830_H_D_FY_C6.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\02830_H_D_FY_C7.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\02830_H_D_FY_C8.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\02844_H_D_FY_C1.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\02844_H_D_FY_C2.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\02844_H_D_FY_C3.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\02844_H_D_FY_C4.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\02844_H_D_FY_C5.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\02844_H_D_FY_C6.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\02844_H_D_FY_C7.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\02844_H_D_FY_C8.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\02871_H_C_BY_C1.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\02871_H_C_BY_C2.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\02871_H_C_BY_C3.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\02871_H_C_BY_C4.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\02871_H_C_BY_C5.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\02871_H_C_BY_C6.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\02871_H_C_BY_C7.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\02871_H_C_BY_C8.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\02874_H_C_FY_C1.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\02874_H_C_FY_C2.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\02874_H_C_FY_C3.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\02874_H_C_FY_C4.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\02874_H_C_FY_C5.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\02874_H_C_FY_C6.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\02874_H_C_FY_C7.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\02874_H_C_FY_C8.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\02879_H_C_BY_C1.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\02879_H_C_BY_C2.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\02879_H_C_BY_C3.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\02879_H_C_BY_C4.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\02879_H_C_BY_C5.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\02879_H_C_BY_C6.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\02879_H_C_BY_C7.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\02879_H_C_BY_C8.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\02900_Y_C_BY_C1.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\02900_Y_C_BY_C2.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\02900_Y_C_BY_C3.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\02900_Y_C_BY_C4.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\02900_Y_C_BY_C5.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\02900_Y_C_BY_C6.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\02900_Y_C_BY_C7.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\02900_Y_C_BY_C8.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\02961_L_F_FY_C1.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\02961_L_F_FY_C2.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\02961_L_F_FY_C3.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\02961_L_F_FY_C4.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\02961_L_F_FY_C5.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\02961_L_F_FY_C6.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\02961_L_F_FY_C7.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\02961_L_F_FY_C8.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\02966_L_F_BY_C1.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\02966_L_F_BY_C2.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\02966_L_F_BY_C3.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\02966_L_F_BY_C4.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\02966_L_F_BY_C5.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\02966_L_F_BY_C6.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\02966_L_F_BY_C7.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\02966_L_F_BY_C8.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\02969_L_F_FY_C1.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\02969_L_F_FY_C2.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\02969_L_F_FY_C3.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\02969_L_F_FY_C4.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\02969_L_F_FY_C5.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\02969_L_F_FY_C6.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\02969_L_F_FY_C7.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\02969_L_F_FY_C8.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\02970_L_F_FY_C1.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\02970_L_F_FY_C2.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\02970_L_F_FY_C3.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\02970_L_F_FY_C4.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\02970_L_F_FY_C5.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\02970_L_F_FY_C6.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\02970_L_F_FY_C7.json
# Processing file: D:\human_fall\re_landmark\re_train_NY_json\02970_L_F_FY_C8.json
# Sample sequence shape: (3, 26)
# c:\Users\user\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\optim\lr_scheduler.py:28: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn("The verbose parameter is deprecated. Please use get_last_lr() "
# Epoch [1/500], Train Loss: 0.7129, Val Loss: 0.6668
# Epoch [2/500], Train Loss: 0.6764, Val Loss: 0.6457
# Epoch [3/500], Train Loss: 0.6613, Val Loss: 0.6350
# Epoch [4/500], Train Loss: 0.6481, Val Loss: 0.6253
# Epoch [5/500], Train Loss: 0.6374, Val Loss: 0.6105
# Epoch [6/500], Train Loss: 0.6251, Val Loss: 0.5941
# Epoch [7/500], Train Loss: 0.6151, Val Loss: 0.5875
# Epoch [8/500], Train Loss: 0.6053, Val Loss: 0.5802
# Epoch [9/500], Train Loss: 0.5964, Val Loss: 0.5714
# Epoch [10/500], Train Loss: 0.5894, Val Loss: 0.5622
# Epoch [11/500], Train Loss: 0.5820, Val Loss: 0.5607
# Epoch [12/500], Train Loss: 0.5745, Val Loss: 0.5503
# Epoch [13/500], Train Loss: 0.5659, Val Loss: 0.5476
# Epoch [14/500], Train Loss: 0.5599, Val Loss: 0.5390
# Epoch [15/500], Train Loss: 0.5537, Val Loss: 0.5355
# Epoch [16/500], Train Loss: 0.5476, Val Loss: 0.5274
# Epoch [17/500], Train Loss: 0.5417, Val Loss: 0.5211
# Epoch [18/500], Train Loss: 0.5377, Val Loss: 0.5197
# Epoch [19/500], Train Loss: 0.5338, Val Loss: 0.5193
# Epoch [20/500], Train Loss: 0.5285, Val Loss: 0.5115
# Epoch [21/500], Train Loss: 0.5235, Val Loss: 0.5101
# Epoch [22/500], Train Loss: 0.5188, Val Loss: 0.5087
# Epoch [23/500], Train Loss: 0.5159, Val Loss: 0.5134
# Epoch [24/500], Train Loss: 0.5104, Val Loss: 0.4951
# Epoch [25/500], Train Loss: 0.5068, Val Loss: 0.4930
# Epoch [26/500], Train Loss: 0.5043, Val Loss: 0.4916
# Epoch [27/500], Train Loss: 0.4993, Val Loss: 0.4900
# Epoch [28/500], Train Loss: 0.4977, Val Loss: 0.4855
# Epoch [29/500], Train Loss: 0.4934, Val Loss: 0.4935
# Epoch [30/500], Train Loss: 0.4894, Val Loss: 0.4824
# Epoch [31/500], Train Loss: 0.4885, Val Loss: 0.4787
# Epoch [32/500], Train Loss: 0.4839, Val Loss: 0.4780
# Epoch [33/500], Train Loss: 0.4814, Val Loss: 0.4790
# Epoch [34/500], Train Loss: 0.4790, Val Loss: 0.4763
# Epoch [35/500], Train Loss: 0.4775, Val Loss: 0.4810
# Epoch [36/500], Train Loss: 0.4722, Val Loss: 0.4749
# Epoch [37/500], Train Loss: 0.4703, Val Loss: 0.4664
# Epoch [38/500], Train Loss: 0.4676, Val Loss: 0.4685
# Epoch [39/500], Train Loss: 0.4656, Val Loss: 0.4710
# Epoch [40/500], Train Loss: 0.4648, Val Loss: 0.4660
# Epoch [41/500], Train Loss: 0.4625, Val Loss: 0.4647
# Epoch [42/500], Train Loss: 0.4597, Val Loss: 0.4618
# Epoch [43/500], Train Loss: 0.4581, Val Loss: 0.4623
# Epoch [44/500], Train Loss: 0.4562, Val Loss: 0.4577
# Epoch [45/500], Train Loss: 0.4538, Val Loss: 0.4624
# Epoch [46/500], Train Loss: 0.4529, Val Loss: 0.4595
# Epoch [47/500], Train Loss: 0.4475, Val Loss: 0.4552
# Epoch [48/500], Train Loss: 0.4492, Val Loss: 0.4512
# Epoch [49/500], Train Loss: 0.4481, Val Loss: 0.4553
# Epoch [50/500], Train Loss: 0.4447, Val Loss: 0.4557
# Epoch [51/500], Train Loss: 0.4428, Val Loss: 0.4580
# Epoch [52/500], Train Loss: 0.4416, Val Loss: 0.4503
# Epoch [53/500], Train Loss: 0.4379, Val Loss: 0.4497
# Epoch [54/500], Train Loss: 0.4370, Val Loss: 0.4598
# Epoch [55/500], Train Loss: 0.4374, Val Loss: 0.4461
# Epoch [56/500], Train Loss: 0.4347, Val Loss: 0.4477
# Epoch [57/500], Train Loss: 0.4363, Val Loss: 0.4406
# Epoch [58/500], Train Loss: 0.4305, Val Loss: 0.4644
# Epoch [59/500], Train Loss: 0.4296, Val Loss: 0.4479
# Epoch [60/500], Train Loss: 0.4288, Val Loss: 0.4459
# Epoch [61/500], Train Loss: 0.4283, Val Loss: 0.4435
# Epoch [62/500], Train Loss: 0.4266, Val Loss: 0.4463
# Epoch [63/500], Train Loss: 0.4244, Val Loss: 0.4506
# Epoch [64/500], Train Loss: 0.4028, Val Loss: 0.4340
# Epoch [65/500], Train Loss: 0.3955, Val Loss: 0.4311
# Epoch [66/500], Train Loss: 0.3926, Val Loss: 0.4338
# Epoch [67/500], Train Loss: 0.3907, Val Loss: 0.4317
# Epoch [68/500], Train Loss: 0.3918, Val Loss: 0.4313
# Epoch [69/500], Train Loss: 0.3913, Val Loss: 0.4313
# Epoch [70/500], Train Loss: 0.3901, Val Loss: 0.4307
# Epoch [71/500], Train Loss: 0.3896, Val Loss: 0.4323
# Epoch [72/500], Train Loss: 0.3875, Val Loss: 0.4327
# Epoch [73/500], Train Loss: 0.3874, Val Loss: 0.4319
# Epoch [74/500], Train Loss: 0.3880, Val Loss: 0.4301
# Epoch [75/500], Train Loss: 0.3874, Val Loss: 0.4302
# Epoch [76/500], Train Loss: 0.3867, Val Loss: 0.4295
# Epoch [77/500], Train Loss: 0.3863, Val Loss: 0.4317
# Epoch [78/500], Train Loss: 0.3863, Val Loss: 0.4304
# Epoch [79/500], Train Loss: 0.3841, Val Loss: 0.4301
# Epoch [80/500], Train Loss: 0.3845, Val Loss: 0.4294
# Epoch [81/500], Train Loss: 0.3849, Val Loss: 0.4306
# Epoch [82/500], Train Loss: 0.3848, Val Loss: 0.4302
# Epoch [83/500], Train Loss: 0.3826, Val Loss: 0.4306
# Epoch [84/500], Train Loss: 0.3837, Val Loss: 0.4294
# Epoch [85/500], Train Loss: 0.3834, Val Loss: 0.4297
# Epoch [86/500], Train Loss: 0.3837, Val Loss: 0.4287
# Epoch [87/500], Train Loss: 0.3824, Val Loss: 0.4305
# Epoch [88/500], Train Loss: 0.3834, Val Loss: 0.4295
# Epoch [89/500], Train Loss: 0.3813, Val Loss: 0.4303
# Epoch [90/500], Train Loss: 0.3805, Val Loss: 0.4283
# Epoch [91/500], Train Loss: 0.3821, Val Loss: 0.4305
# Epoch [92/500], Train Loss: 0.3804, Val Loss: 0.4317
# Epoch [93/500], Train Loss: 0.3807, Val Loss: 0.4287
# Epoch [94/500], Train Loss: 0.3797, Val Loss: 0.4292
# Epoch [95/500], Train Loss: 0.3775, Val Loss: 0.4324
# Epoch [96/500], Train Loss: 0.3776, Val Loss: 0.4289
# Epoch [97/500], Train Loss: 0.3771, Val Loss: 0.4284
# Epoch [98/500], Train Loss: 0.3778, Val Loss: 0.4283
# Epoch [99/500], Train Loss: 0.3742, Val Loss: 0.4287
# Epoch [100/500], Train Loss: 0.3752, Val Loss: 0.4286
# Epoch [101/500], Train Loss: 0.3752, Val Loss: 0.4285
# Epoch [102/500], Train Loss: 0.3740, Val Loss: 0.4290
# Epoch [103/500], Train Loss: 0.3758, Val Loss: 0.4289
# Epoch [104/500], Train Loss: 0.3742, Val Loss: 0.4289
# Epoch [105/500], Train Loss: 0.3751, Val Loss: 0.4289
# Epoch [106/500], Train Loss: 0.3755, Val Loss: 0.4290
# Epoch [107/500], Train Loss: 0.3767, Val Loss: 0.4289
# Epoch [108/500], Train Loss: 0.3748, Val Loss: 0.4290
# Epoch [109/500], Train Loss: 0.3745, Val Loss: 0.4290
# Epoch [110/500], Train Loss: 0.3742, Val Loss: 0.4290
# Epoch [111/500], Train Loss: 0.3754, Val Loss: 0.4290
# Epoch [112/500], Train Loss: 0.3746, Val Loss: 0.4290
# Epoch [113/500], Train Loss: 0.3745, Val Loss: 0.4290
# Epoch [114/500], Train Loss: 0.3767, Val Loss: 0.4290
# Epoch [115/500], Train Loss: 0.3769, Val Loss: 0.4290
# Epoch [116/500], Train Loss: 0.3753, Val Loss: 0.4290
# Epoch [117/500], Train Loss: 0.3754, Val Loss: 0.4290
# Epoch [118/500], Train Loss: 0.3764, Val Loss: 0.4290
# Epoch [119/500], Train Loss: 0.3755, Val Loss: 0.4290
# Epoch [120/500], Train Loss: 0.3749, Val Loss: 0.4290
# Epoch [121/500], Train Loss: 0.3757, Val Loss: 0.4290
# Epoch [122/500], Train Loss: 0.3758, Val Loss: 0.4290
# Epoch [123/500], Train Loss: 0.3746, Val Loss: 0.4290
# Epoch [124/500], Train Loss: 0.3763, Val Loss: 0.4290
# Epoch [125/500], Train Loss: 0.3767, Val Loss: 0.4290
# Epoch [126/500], Train Loss: 0.3748, Val Loss: 0.4290
# Epoch [127/500], Train Loss: 0.3758, Val Loss: 0.4290
# Epoch [128/500], Train Loss: 0.3747, Val Loss: 0.4290
# Epoch [129/500], Train Loss: 0.3768, Val Loss: 0.4290
# Epoch [130/500], Train Loss: 0.3757, Val Loss: 0.4290
# Epoch [131/500], Train Loss: 0.3740, Val Loss: 0.4290
# Epoch [132/500], Train Loss: 0.3750, Val Loss: 0.4290
# Epoch [133/500], Train Loss: 0.3753, Val Loss: 0.4290
# Epoch [134/500], Train Loss: 0.3744, Val Loss: 0.4290
# Epoch [135/500], Train Loss: 0.3746, Val Loss: 0.4290
# Epoch [136/500], Train Loss: 0.3753, Val Loss: 0.4290
# Epoch [137/500], Train Loss: 0.3746, Val Loss: 0.4290
# Epoch [138/500], Train Loss: 0.3751, Val Loss: 0.4290
# Epoch [139/500], Train Loss: 0.3765, Val Loss: 0.4290
# Epoch [140/500], Train Loss: 0.3758, Val Loss: 0.4290
# Epoch [141/500], Train Loss: 0.3733, Val Loss: 0.4290
# Epoch [142/500], Train Loss: 0.3755, Val Loss: 0.4290
# Epoch [143/500], Train Loss: 0.3756, Val Loss: 0.4290
# Epoch [144/500], Train Loss: 0.3735, Val Loss: 0.4290
# Epoch [145/500], Train Loss: 0.3751, Val Loss: 0.4290
# Epoch [146/500], Train Loss: 0.3772, Val Loss: 0.4290
# Epoch [147/500], Train Loss: 0.3749, Val Loss: 0.4290
# Epoch [148/500], Train Loss: 0.3769, Val Loss: 0.4290
# Early stopping
# Train F1: 0.8506, Val F1: 0.8183
# Train CM:
# [[31926   187  1858]
#  [ 3174   583  2699]
#  [ 2074   212 39319]]
# Val CM:
# [[7615   54  779]
#  [ 772  104  647]
#  [ 924   62 9551]]
# Training completed

# %% [markdown]
# ### sensordata를 포함해 클래스를 재정의한 json 파일로 다시 훈련

# %%
LANDMARKS = [0, 11, 12, 15, 16, 23, 24, 25, 26, 27, 28]

# 데이터 증강 삭제
# 데이터셋 클래스 정의
class FallSequenceDataset(Dataset):
    def __init__(self, json_files, sequence_length=3):
        self.sequence_length = sequence_length
        self.sequences = []
        self.labels = []
        self.scaler = StandardScaler()
        print(f"LANDMARKS length: {len(LANDMARKS)}")
        
        if self.sequences:
            print(f"sequence shape : {self.sequences[0].shape}")
            print(f"랜드마크 수 : {len(LANDMARKS)}")
            print(f"Features / landmark: {self.sequences[0].shape[1] // len(LANDMARKS)}")
            print(f"전체 features per frame: {self.sequences[0].shape[1]}")
        else:
            print("시퀀스 생성 실패")
    
        all_landmarks = []
        
        for json_file in json_files:
            print(f'Processing file: {json_file}')
            with open(json_file, 'r') as f:
                data = json.load(f)
            
            frames = list(data['pose_data'].values())
            
            for i in range(0, len(frames) - self.sequence_length + 1):
                sequence = frames[i:i+self.sequence_length]
                landmarks = []
                
                for frame in sequence:
                    frame_landmarks = []
                    for landmark in LANDMARKS:
                        frame_landmarks.extend([
                            frame[f'landmark_{landmark}']['x'],
                            frame[f'landmark_{landmark}']['y']
                        ])
                    landmarks.append(frame_landmarks)
                
                all_landmarks.extend(landmarks)
                
                # 마지막 프레임의 클래스를 레이블로 사용
                label = 0 if frame['class'] == 'Normal' else (1 if frame['class'] == 'Danger' else 2)
                
                self.sequences.append(landmarks)
                self.labels.append(label)
        
        # 전체 데이터 정규화
        all_landmarks = np.array(all_landmarks)
        all_landmarks_scaled = self.scaler.fit_transform(all_landmarks)
        
        # 정규화된 데이터를 다시 시퀀스로 재구성
        for i in range(len(self.sequences)):
            start = i * self.sequence_length
            end = start + self.sequence_length
            self.sequences[i] = all_landmarks_scaled[start:end]
        
        if self.sequences:
            print(f"sequence shape: {self.sequences[0].shape}")
        else:
            print("sequences 생성 실패")

    def __len__(self):
        return len(self.sequences)

    def __getitem__(self, idx):
        if idx >= len(self.sequences):
            raise IndexError(f"Index {idx} out of range. Dataset length: {len(self.sequences)}")
        sequence = self.sequences[idx]
        return torch.FloatTensor(sequence), torch.LongTensor([self.labels[idx]]).squeeze()

# GRU 모델 정의
class FallDetectionGRU(nn.Module):
    def __init__(self, input_size, hidden_size=64, num_layers=2, output_size=3, dropout=0.5):
        super(FallDetectionGRU, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.gru = nn.GRU(input_size, hidden_size, num_layers, batch_first=True, dropout=dropout)
        self.fc = nn.Linear(hidden_size, output_size)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(x.device)
        out, _ = self.gru(x, h0)
        out = self.dropout(out[:, -1, :])
        out = self.fc(out)
        return out

# 데이터 로드 및 전처리
json_folder = 'D:\\human_fall\\re_landmark\\addition_json'
json_files = [os.path.join(json_folder, f) for f in os.listdir(json_folder) if f.endswith('.json')]
dataset = FallSequenceDataset(json_files)

# 데이터셋을 학습 및 검증 세트로 분할
train_indices, val_indices = train_test_split(range(len(dataset)), test_size=0.2)
train_dataset = torch.utils.data.Subset(dataset, train_indices)
val_dataset = torch.utils.data.Subset(dataset, val_indices)

# 데이터 로더 생성 전에 클래스 가중치 계산
class_weights = compute_class_weight('balanced', classes=np.unique(dataset.labels), y=dataset.labels)
class_weights = torch.FloatTensor(class_weights).to(device)

# 손실 함수에 가중치 적용
criterion = nn.CrossEntropyLoss(weight=class_weights)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=32)

if len(dataset) > 0:
    sample_sequence, sample_label = dataset[0]
    input_size = sample_sequence.shape[1]
    print(f'input_size :', {input_size})
    model = FallDetectionGRU(input_size).to(device)
else:
    print("데이터 없음")
    exit()

optimizer = torch.optim.Adam(model.parameters(), lr=0.001, weight_decay=1e-5)
scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=5, verbose=True)
num_epochs = 500
best_loss = float('inf')
patience = 50
no_improve = 0

for epoch in range(num_epochs):
    model.train()
    total_loss_train = 0
    
    for sequences, labels in train_loader:
        sequences, labels = sequences.to(device), labels.to(device)
        
        optimizer.zero_grad()
        outputs = model(sequences)
        loss_train = criterion(outputs, labels.view(-1))
        loss_train.backward()
        optimizer.step()
        
        total_loss_train += loss_train.item()
    
    avg_loss_train = total_loss_train / len(train_loader)

    # 검증 단계
    model.eval()
    total_loss_val = 0
    
    with torch.no_grad():
        for sequences_val, labels_val in val_loader:
            sequences_val, labels_val = sequences_val.to(device), labels_val.to(device)
            outputs_val = model(sequences_val)
            loss_val = criterion(outputs_val, labels_val.view(-1))
            total_loss_val += loss_val.item()
    
    avg_loss_val = total_loss_val / len(val_loader)

    print(f'Epoch [{epoch+1}/{num_epochs}], Train Loss: {avg_loss_train:.4f}, Val Loss: {avg_loss_val:.4f}')
    scheduler.step(avg_loss_val)
    
    if avg_loss_val < best_loss:
        best_loss = avg_loss_val
        no_improve = 0
        torch.save(model.state_dict(), 'add_sensordata.pt')
    else:
        no_improve += 1
    
    if no_improve >= patience:
        print("Early stopping")
        break

def calculate_metrics(model, data_loader):
    model.eval()
    all_preds = []
    all_labels = []
    with torch.no_grad():
        for sequences, labels in data_loader:
            sequences, labels = sequences.to(device), labels.to(device)
            outputs = model(sequences)
            _, preds = torch.max(outputs, 1)
            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())
    
    f1 = f1_score(all_labels, all_preds, average='weighted')
    cm = confusion_matrix(all_labels, all_preds)
    return f1, cm

# 학습 루프 내에서 성능 지표 계산
train_f1, train_cm = calculate_metrics(model, train_loader)
val_f1, val_cm = calculate_metrics(model, val_loader)
print(f'Train F1: {train_f1:.4f}, Val F1: {val_f1:.4f}')
print(f'Train CM:\n{train_cm}\nVal CM:\n{val_cm}')

print("학습 완료")
# Out:
# LANDMARKS length: 11
# 시퀀스 생성 실패
# Processing file: D:\human_fall\re_landmark\addition_json\00060_H_A_SY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_json\00060_H_A_SY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_json\00060_H_A_SY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_json\00060_H_A_SY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_json\00060_H_A_SY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_json\00060_H_A_SY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_json\00060_H_A_SY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_json\00060_H_A_SY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_json\00093_H_A_FY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_json\00093_H_A_FY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_json\00093_H_A_FY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_json\00093_H_A_FY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_json\00093_H_A_FY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_json\00093_H_A_FY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_json\00093_H_A_FY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_json\00093_H_A_FY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_json\00096_H_A_FY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_json\00096_H_A_FY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_json\00096_H_A_FY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_json\00096_H_A_FY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_json\00096_H_A_FY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_json\00096_H_A_FY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_json\00096_H_A_FY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_json\00096_H_A_FY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_json\00108_H_A_SY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_json\00108_H_A_SY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_json\00108_H_A_SY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_json\00108_H_A_SY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_json\00108_H_A_SY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_json\00108_H_A_SY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_json\00108_H_A_SY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_json\00108_H_A_SY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_json\00112_H_A_SY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_json\00112_H_A_SY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_json\00112_H_A_SY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_json\00112_H_A_SY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_json\00112_H_A_SY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_json\00112_H_A_SY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_json\00112_H_A_SY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_json\00112_H_A_SY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_json\00114_H_A_BY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_json\00114_H_A_BY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_json\00114_H_A_BY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_json\00114_H_A_BY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_json\00114_H_A_BY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_json\00114_H_A_BY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_json\00114_H_A_BY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_json\00114_H_A_BY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_json\00121_H_A_N_C1.json
# Processing file: D:\human_fall\re_landmark\addition_json\00121_H_A_N_C2.json
# Processing file: D:\human_fall\re_landmark\addition_json\00121_H_A_N_C3.json
# Processing file: D:\human_fall\re_landmark\addition_json\00121_H_A_N_C4.json
# Processing file: D:\human_fall\re_landmark\addition_json\00121_H_A_N_C5.json
# Processing file: D:\human_fall\re_landmark\addition_json\00121_H_A_N_C6.json
# Processing file: D:\human_fall\re_landmark\addition_json\00121_H_A_N_C7.json
# Processing file: D:\human_fall\re_landmark\addition_json\00121_H_A_N_C8.json
# Processing file: D:\human_fall\re_landmark\addition_json\00130_H_A_FY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_json\00130_H_A_FY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_json\00130_H_A_FY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_json\00130_H_A_FY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_json\00130_H_A_FY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_json\00130_H_A_FY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_json\00130_H_A_FY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_json\00130_H_A_FY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_json\00132_H_A_BY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_json\00132_H_A_BY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_json\00132_H_A_BY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_json\00132_H_A_BY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_json\00132_H_A_BY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_json\00132_H_A_BY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_json\00132_H_A_BY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_json\00132_H_A_BY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_json\00158_H_A_SY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_json\00158_H_A_SY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_json\00158_H_A_SY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_json\00158_H_A_SY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_json\00158_H_A_SY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_json\00158_H_A_SY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_json\00158_H_A_SY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_json\00158_H_A_SY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_json\00164_H_A_N_C1.json
# Processing file: D:\human_fall\re_landmark\addition_json\00164_H_A_N_C2.json
# Processing file: D:\human_fall\re_landmark\addition_json\00164_H_A_N_C3.json
# Processing file: D:\human_fall\re_landmark\addition_json\00164_H_A_N_C4.json
# Processing file: D:\human_fall\re_landmark\addition_json\00164_H_A_N_C5.json
# Processing file: D:\human_fall\re_landmark\addition_json\00164_H_A_N_C6.json
# Processing file: D:\human_fall\re_landmark\addition_json\00164_H_A_N_C7.json
# Processing file: D:\human_fall\re_landmark\addition_json\00164_H_A_N_C8.json
# Processing file: D:\human_fall\re_landmark\addition_json\00171_H_A_BY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_json\00171_H_A_BY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_json\00171_H_A_BY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_json\00171_H_A_BY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_json\00171_H_A_BY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_json\00171_H_A_BY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_json\00171_H_A_BY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_json\00171_H_A_BY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_json\00172_H_A_N_C1.json
# Processing file: D:\human_fall\re_landmark\addition_json\00172_H_A_N_C2.json
# Processing file: D:\human_fall\re_landmark\addition_json\00172_H_A_N_C3.json
# Processing file: D:\human_fall\re_landmark\addition_json\00172_H_A_N_C4.json
# Processing file: D:\human_fall\re_landmark\addition_json\00172_H_A_N_C5.json
# Processing file: D:\human_fall\re_landmark\addition_json\00172_H_A_N_C6.json
# Processing file: D:\human_fall\re_landmark\addition_json\00172_H_A_N_C7.json
# Processing file: D:\human_fall\re_landmark\addition_json\00172_H_A_N_C8.json
# Processing file: D:\human_fall\re_landmark\addition_json\00174_H_A_SY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_json\00174_H_A_SY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_json\00174_H_A_SY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_json\00174_H_A_SY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_json\00174_H_A_SY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_json\00174_H_A_SY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_json\00174_H_A_SY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_json\00174_H_A_SY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_json\00175_H_A_BY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_json\00175_H_A_BY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_json\00175_H_A_BY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_json\00175_H_A_BY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_json\00175_H_A_BY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_json\00175_H_A_BY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_json\00175_H_A_BY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_json\00175_H_A_BY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_json\00188_H_A_N_C1.json
# Processing file: D:\human_fall\re_landmark\addition_json\00188_H_A_N_C2.json
# Processing file: D:\human_fall\re_landmark\addition_json\00188_H_A_N_C3.json
# Processing file: D:\human_fall\re_landmark\addition_json\00188_H_A_N_C4.json
# Processing file: D:\human_fall\re_landmark\addition_json\00188_H_A_N_C5.json
# Processing file: D:\human_fall\re_landmark\addition_json\00188_H_A_N_C6.json
# Processing file: D:\human_fall\re_landmark\addition_json\00188_H_A_N_C7.json
# Processing file: D:\human_fall\re_landmark\addition_json\00188_H_A_N_C8.json
# Processing file: D:\human_fall\re_landmark\addition_json\00191_H_A_BY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_json\00191_H_A_BY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_json\00191_H_A_BY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_json\00191_H_A_BY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_json\00191_H_A_BY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_json\00191_H_A_BY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_json\00191_H_A_BY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_json\00191_H_A_BY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_json\00193_H_A_FY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_json\00193_H_A_FY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_json\00193_H_A_FY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_json\00193_H_A_FY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_json\00193_H_A_FY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_json\00193_H_A_FY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_json\00193_H_A_FY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_json\00193_H_A_FY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_json\00194_H_A_SY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_json\00194_H_A_SY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_json\00194_H_A_SY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_json\00194_H_A_SY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_json\00194_H_A_SY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_json\00194_H_A_SY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_json\00194_H_A_SY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_json\00194_H_A_SY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_json\00247_H_D_BY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_json\00247_H_D_BY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_json\00247_H_D_BY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_json\00247_H_D_BY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_json\00247_H_D_BY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_json\00247_H_D_BY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_json\00247_H_D_BY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_json\00247_H_D_BY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_json\00258_H_D_SY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_json\00258_H_D_SY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_json\00258_H_D_SY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_json\00258_H_D_SY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_json\00258_H_D_SY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_json\00258_H_D_SY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_json\00258_H_D_SY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_json\00258_H_D_SY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_json\00265_H_D_FY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_json\00265_H_D_FY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_json\00265_H_D_FY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_json\00265_H_D_FY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_json\00265_H_D_FY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_json\00265_H_D_FY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_json\00265_H_D_FY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_json\00265_H_D_FY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_json\00269_H_D_FY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_json\00269_H_D_FY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_json\00269_H_D_FY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_json\00269_H_D_FY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_json\00269_H_D_FY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_json\00269_H_D_FY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_json\00269_H_D_FY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_json\00269_H_D_FY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_json\00291_H_A_BY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_json\00291_H_A_BY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_json\00291_H_A_BY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_json\00291_H_A_BY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_json\00291_H_A_BY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_json\00291_H_A_BY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_json\00291_H_A_BY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_json\00291_H_A_BY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_json\00299_H_A_BY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_json\00299_H_A_BY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_json\00299_H_A_BY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_json\00299_H_A_BY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_json\00299_H_A_BY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_json\00299_H_A_BY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_json\00299_H_A_BY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_json\00299_H_A_BY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_json\00302_H_A_BY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_json\00302_H_A_BY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_json\00302_H_A_BY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_json\00302_H_A_BY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_json\00302_H_A_BY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_json\00302_H_A_BY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_json\00302_H_A_BY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_json\00302_H_A_BY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_json\00323_H_A_FY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_json\00323_H_A_FY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_json\00323_H_A_FY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_json\00323_H_A_FY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_json\00323_H_A_FY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_json\00323_H_A_FY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_json\00323_H_A_FY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_json\00323_H_A_FY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_json\00341_H_A_SY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_json\00341_H_A_SY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_json\00341_H_A_SY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_json\00341_H_A_SY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_json\00341_H_A_SY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_json\00341_H_A_SY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_json\00341_H_A_SY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_json\00341_H_A_SY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_json\00478_H_A_BY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_json\00478_H_A_BY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_json\00478_H_A_BY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_json\00478_H_A_BY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_json\00478_H_A_BY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_json\00478_H_A_BY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_json\00478_H_A_BY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_json\00478_H_A_BY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_json\00480_H_A_BY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_json\00480_H_A_BY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_json\00480_H_A_BY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_json\00480_H_A_BY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_json\00480_H_A_BY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_json\00480_H_A_BY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_json\00480_H_A_BY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_json\00480_H_A_BY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_json\00486_H_D_N_C1.json
# Processing file: D:\human_fall\re_landmark\addition_json\00486_H_D_N_C2.json
# Processing file: D:\human_fall\re_landmark\addition_json\00486_H_D_N_C3.json
# Processing file: D:\human_fall\re_landmark\addition_json\00486_H_D_N_C4.json
# Processing file: D:\human_fall\re_landmark\addition_json\00486_H_D_N_C5.json
# Processing file: D:\human_fall\re_landmark\addition_json\00486_H_D_N_C6.json
# Processing file: D:\human_fall\re_landmark\addition_json\00486_H_D_N_C7.json
# Processing file: D:\human_fall\re_landmark\addition_json\00486_H_D_N_C8.json
# Processing file: D:\human_fall\re_landmark\addition_json\00505_H_D_FY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_json\00505_H_D_FY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_json\00505_H_D_FY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_json\00505_H_D_FY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_json\00505_H_D_FY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_json\00505_H_D_FY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_json\00505_H_D_FY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_json\00505_H_D_FY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_json\00526_H_D_FY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_json\00526_H_D_FY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_json\00526_H_D_FY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_json\00526_H_D_FY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_json\00526_H_D_FY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_json\00526_H_D_FY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_json\00526_H_D_FY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_json\00526_H_D_FY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_json\00533_H_D_N_C1.json
# Processing file: D:\human_fall\re_landmark\addition_json\00533_H_D_N_C2.json
# Processing file: D:\human_fall\re_landmark\addition_json\00533_H_D_N_C3.json
# Processing file: D:\human_fall\re_landmark\addition_json\00533_H_D_N_C4.json
# Processing file: D:\human_fall\re_landmark\addition_json\00533_H_D_N_C5.json
# Processing file: D:\human_fall\re_landmark\addition_json\00533_H_D_N_C6.json
# Processing file: D:\human_fall\re_landmark\addition_json\00533_H_D_N_C7.json
# Processing file: D:\human_fall\re_landmark\addition_json\00533_H_D_N_C8.json
# Processing file: D:\human_fall\re_landmark\addition_json\00548_H_D_FY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_json\00548_H_D_FY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_json\00548_H_D_FY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_json\00548_H_D_FY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_json\00548_H_D_FY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_json\00548_H_D_FY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_json\00548_H_D_FY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_json\00548_H_D_FY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_json\00574_H_D_FY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_json\00574_H_D_FY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_json\00574_H_D_FY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_json\00574_H_D_FY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_json\00574_H_D_FY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_json\00574_H_D_FY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_json\00574_H_D_FY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_json\00574_H_D_FY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_json\00593_H_D_BY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_json\00593_H_D_BY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_json\00593_H_D_BY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_json\00593_H_D_BY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_json\00593_H_D_BY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_json\00593_H_D_BY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_json\00593_H_D_BY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_json\00593_H_D_BY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_json\00596_H_D_FY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_json\00596_H_D_FY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_json\00596_H_D_FY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_json\00596_H_D_FY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_json\00596_H_D_FY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_json\00596_H_D_FY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_json\00596_H_D_FY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_json\00596_H_D_FY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_json\00615_H_D_SY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_json\00615_H_D_SY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_json\00615_H_D_SY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_json\00615_H_D_SY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_json\00615_H_D_SY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_json\00615_H_D_SY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_json\00615_H_D_SY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_json\00615_H_D_SY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_json\00619_H_D_FY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_json\00619_H_D_FY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_json\00619_H_D_FY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_json\00619_H_D_FY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_json\00619_H_D_FY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_json\00619_H_D_FY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_json\00619_H_D_FY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_json\00619_H_D_FY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_json\00665_H_D_FY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_json\00665_H_D_FY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_json\00665_H_D_FY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_json\00665_H_D_FY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_json\00665_H_D_FY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_json\00665_H_D_FY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_json\00665_H_D_FY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_json\00665_H_D_FY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_json\00676_H_D_SY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_json\00676_H_D_SY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_json\00676_H_D_SY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_json\00676_H_D_SY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_json\00676_H_D_SY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_json\00676_H_D_SY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_json\00676_H_D_SY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_json\00676_H_D_SY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_json\00690_H_D_N_C1.json
# Processing file: D:\human_fall\re_landmark\addition_json\00690_H_D_N_C2.json
# Processing file: D:\human_fall\re_landmark\addition_json\00690_H_D_N_C3.json
# Processing file: D:\human_fall\re_landmark\addition_json\00690_H_D_N_C4.json
# Processing file: D:\human_fall\re_landmark\addition_json\00690_H_D_N_C5.json
# Processing file: D:\human_fall\re_landmark\addition_json\00690_H_D_N_C6.json
# Processing file: D:\human_fall\re_landmark\addition_json\00690_H_D_N_C7.json
# Processing file: D:\human_fall\re_landmark\addition_json\00690_H_D_N_C8.json
# Processing file: D:\human_fall\re_landmark\addition_json\00704_H_D_FY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_json\00704_H_D_FY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_json\00704_H_D_FY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_json\00704_H_D_FY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_json\00704_H_D_FY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_json\00704_H_D_FY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_json\00704_H_D_FY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_json\00704_H_D_FY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_json\00705_H_D_BY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_json\00705_H_D_BY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_json\00705_H_D_BY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_json\00705_H_D_BY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_json\00705_H_D_BY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_json\00705_H_D_BY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_json\00705_H_D_BY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_json\00705_H_D_BY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_json\00707_H_D_BY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_json\00707_H_D_BY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_json\00707_H_D_BY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_json\00707_H_D_BY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_json\00707_H_D_BY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_json\00707_H_D_BY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_json\00707_H_D_BY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_json\00707_H_D_BY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_json\00712_H_D_BY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_json\00712_H_D_BY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_json\00712_H_D_BY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_json\00712_H_D_BY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_json\00712_H_D_BY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_json\00712_H_D_BY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_json\00712_H_D_BY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_json\00712_H_D_BY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_json\00737_H_D_BY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_json\00737_H_D_BY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_json\00737_H_D_BY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_json\00737_H_D_BY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_json\00737_H_D_BY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_json\00737_H_D_BY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_json\00737_H_D_BY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_json\00737_H_D_BY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_json\00751_O_E_N_C1.json
# Processing file: D:\human_fall\re_landmark\addition_json\00751_O_E_N_C2.json
# Processing file: D:\human_fall\re_landmark\addition_json\00751_O_E_N_C3.json
# Processing file: D:\human_fall\re_landmark\addition_json\00751_O_E_N_C4.json
# Processing file: D:\human_fall\re_landmark\addition_json\00751_O_E_N_C5.json
# Processing file: D:\human_fall\re_landmark\addition_json\00751_O_E_N_C6.json
# Processing file: D:\human_fall\re_landmark\addition_json\00751_O_E_N_C7.json
# Processing file: D:\human_fall\re_landmark\addition_json\00751_O_E_N_C8.json
# Processing file: D:\human_fall\re_landmark\addition_json\00758_O_E_N_C1.json
# Processing file: D:\human_fall\re_landmark\addition_json\00758_O_E_N_C2.json
# Processing file: D:\human_fall\re_landmark\addition_json\00758_O_E_N_C3.json
# Processing file: D:\human_fall\re_landmark\addition_json\00758_O_E_N_C4.json
# Processing file: D:\human_fall\re_landmark\addition_json\00758_O_E_N_C5.json
# Processing file: D:\human_fall\re_landmark\addition_json\00758_O_E_N_C6.json
# Processing file: D:\human_fall\re_landmark\addition_json\00758_O_E_N_C7.json
# Processing file: D:\human_fall\re_landmark\addition_json\00758_O_E_N_C8.json
# Processing file: D:\human_fall\re_landmark\addition_json\00777_O_E_N_C1.json
# Processing file: D:\human_fall\re_landmark\addition_json\00777_O_E_N_C2.json
# Processing file: D:\human_fall\re_landmark\addition_json\00777_O_E_N_C3.json
# Processing file: D:\human_fall\re_landmark\addition_json\00777_O_E_N_C4.json
# Processing file: D:\human_fall\re_landmark\addition_json\00777_O_E_N_C5.json
# Processing file: D:\human_fall\re_landmark\addition_json\00777_O_E_N_C6.json
# Processing file: D:\human_fall\re_landmark\addition_json\00777_O_E_N_C7.json
# Processing file: D:\human_fall\re_landmark\addition_json\00777_O_E_N_C8.json
# Processing file: D:\human_fall\re_landmark\addition_json\00788_O_E_N_C1.json
# Processing file: D:\human_fall\re_landmark\addition_json\00788_O_E_N_C2.json
# Processing file: D:\human_fall\re_landmark\addition_json\00788_O_E_N_C3.json
# Processing file: D:\human_fall\re_landmark\addition_json\00788_O_E_N_C4.json
# Processing file: D:\human_fall\re_landmark\addition_json\00788_O_E_N_C5.json
# Processing file: D:\human_fall\re_landmark\addition_json\00788_O_E_N_C6.json
# Processing file: D:\human_fall\re_landmark\addition_json\00788_O_E_N_C7.json
# Processing file: D:\human_fall\re_landmark\addition_json\00788_O_E_N_C8.json
# Processing file: D:\human_fall\re_landmark\addition_json\00792_O_E_N_C1.json
# Processing file: D:\human_fall\re_landmark\addition_json\00792_O_E_N_C2.json
# Processing file: D:\human_fall\re_landmark\addition_json\00792_O_E_N_C3.json
# Processing file: D:\human_fall\re_landmark\addition_json\00792_O_E_N_C4.json
# Processing file: D:\human_fall\re_landmark\addition_json\00792_O_E_N_C5.json
# Processing file: D:\human_fall\re_landmark\addition_json\00792_O_E_N_C6.json
# Processing file: D:\human_fall\re_landmark\addition_json\00792_O_E_N_C7.json
# Processing file: D:\human_fall\re_landmark\addition_json\00792_O_E_N_C8.json
# Processing file: D:\human_fall\re_landmark\addition_json\00799_O_E_N_C1.json
# Processing file: D:\human_fall\re_landmark\addition_json\00799_O_E_N_C2.json
# Processing file: D:\human_fall\re_landmark\addition_json\00799_O_E_N_C3.json
# Processing file: D:\human_fall\re_landmark\addition_json\00799_O_E_N_C4.json
# Processing file: D:\human_fall\re_landmark\addition_json\00799_O_E_N_C5.json
# Processing file: D:\human_fall\re_landmark\addition_json\00799_O_E_N_C6.json
# Processing file: D:\human_fall\re_landmark\addition_json\00799_O_E_N_C7.json
# Processing file: D:\human_fall\re_landmark\addition_json\00799_O_E_N_C8.json
# Processing file: D:\human_fall\re_landmark\addition_json\00815_O_E_BY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_json\00815_O_E_BY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_json\00815_O_E_BY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_json\00815_O_E_BY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_json\00815_O_E_BY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_json\00815_O_E_BY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_json\00815_O_E_BY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_json\00815_O_E_BY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_json\00864_O_E_FY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_json\00864_O_E_FY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_json\00864_O_E_FY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_json\00864_O_E_FY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_json\00864_O_E_FY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_json\00864_O_E_FY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_json\00864_O_E_FY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_json\00864_O_E_FY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_json\00867_O_E_FY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_json\00867_O_E_FY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_json\00867_O_E_FY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_json\00867_O_E_FY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_json\00867_O_E_FY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_json\00867_O_E_FY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_json\00867_O_E_FY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_json\00867_O_E_FY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_json\00879_O_E_FY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_json\00879_O_E_FY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_json\00879_O_E_FY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_json\00879_O_E_FY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_json\00879_O_E_FY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_json\00879_O_E_FY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_json\00879_O_E_FY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_json\00879_O_E_FY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_json\00888_O_E_N_C1.json
# Processing file: D:\human_fall\re_landmark\addition_json\00888_O_E_N_C2.json
# Processing file: D:\human_fall\re_landmark\addition_json\00888_O_E_N_C3.json
# Processing file: D:\human_fall\re_landmark\addition_json\00888_O_E_N_C4.json
# Processing file: D:\human_fall\re_landmark\addition_json\00888_O_E_N_C5.json
# Processing file: D:\human_fall\re_landmark\addition_json\00888_O_E_N_C6.json
# Processing file: D:\human_fall\re_landmark\addition_json\00888_O_E_N_C7.json
# Processing file: D:\human_fall\re_landmark\addition_json\00888_O_E_N_C8.json
# Processing file: D:\human_fall\re_landmark\addition_json\00896_O_E_FY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_json\00896_O_E_FY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_json\00896_O_E_FY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_json\00896_O_E_FY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_json\00896_O_E_FY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_json\00896_O_E_FY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_json\00896_O_E_FY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_json\00896_O_E_FY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_json\00902_O_E_FY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_json\00902_O_E_FY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_json\00902_O_E_FY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_json\00902_O_E_FY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_json\00902_O_E_FY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_json\00902_O_E_FY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_json\00902_O_E_FY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_json\00902_O_E_FY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_json\00945_O_E_FY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_json\00945_O_E_FY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_json\00945_O_E_FY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_json\00945_O_E_FY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_json\00945_O_E_FY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_json\00945_O_E_FY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_json\00945_O_E_FY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_json\00945_O_E_FY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_json\00969_O_E_BY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_json\00969_O_E_BY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_json\00969_O_E_BY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_json\00969_O_E_BY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_json\00969_O_E_BY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_json\00969_O_E_BY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_json\00969_O_E_BY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_json\00969_O_E_BY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_json\00983_O_E_N_C1.json
# Processing file: D:\human_fall\re_landmark\addition_json\00983_O_E_N_C2.json
# Processing file: D:\human_fall\re_landmark\addition_json\00983_O_E_N_C3.json
# Processing file: D:\human_fall\re_landmark\addition_json\00983_O_E_N_C4.json
# Processing file: D:\human_fall\re_landmark\addition_json\00983_O_E_N_C5.json
# Processing file: D:\human_fall\re_landmark\addition_json\00983_O_E_N_C6.json
# Processing file: D:\human_fall\re_landmark\addition_json\00983_O_E_N_C7.json
# Processing file: D:\human_fall\re_landmark\addition_json\00983_O_E_N_C8.json
# Processing file: D:\human_fall\re_landmark\addition_json\00998_O_E_FY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_json\00998_O_E_FY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_json\00998_O_E_FY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_json\00998_O_E_FY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_json\00998_O_E_FY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_json\00998_O_E_FY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_json\00998_O_E_FY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_json\00998_O_E_FY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_json\01006_O_E_FY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_json\01006_O_E_FY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_json\01006_O_E_FY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_json\01006_O_E_FY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_json\01006_O_E_FY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_json\01006_O_E_FY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_json\01006_O_E_FY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_json\01006_O_E_FY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_json\01054_O_E_N_C1.json
# Processing file: D:\human_fall\re_landmark\addition_json\01054_O_E_N_C2.json
# Processing file: D:\human_fall\re_landmark\addition_json\01054_O_E_N_C3.json
# Processing file: D:\human_fall\re_landmark\addition_json\01054_O_E_N_C4.json
# Processing file: D:\human_fall\re_landmark\addition_json\01054_O_E_N_C5.json
# Processing file: D:\human_fall\re_landmark\addition_json\01054_O_E_N_C6.json
# Processing file: D:\human_fall\re_landmark\addition_json\01054_O_E_N_C7.json
# Processing file: D:\human_fall\re_landmark\addition_json\01054_O_E_N_C8.json
# Processing file: D:\human_fall\re_landmark\addition_json\01089_O_E_N_C1.json
# Processing file: D:\human_fall\re_landmark\addition_json\01089_O_E_N_C2.json
# Processing file: D:\human_fall\re_landmark\addition_json\01089_O_E_N_C3.json
# Processing file: D:\human_fall\re_landmark\addition_json\01089_O_E_N_C4.json
# Processing file: D:\human_fall\re_landmark\addition_json\01089_O_E_N_C5.json
# Processing file: D:\human_fall\re_landmark\addition_json\01089_O_E_N_C6.json
# Processing file: D:\human_fall\re_landmark\addition_json\01089_O_E_N_C7.json
# Processing file: D:\human_fall\re_landmark\addition_json\01089_O_E_N_C8.json
# Processing file: D:\human_fall\re_landmark\addition_json\01112_O_E_N_C1.json
# Processing file: D:\human_fall\re_landmark\addition_json\01112_O_E_N_C2.json
# Processing file: D:\human_fall\re_landmark\addition_json\01112_O_E_N_C3.json
# Processing file: D:\human_fall\re_landmark\addition_json\01112_O_E_N_C4.json
# Processing file: D:\human_fall\re_landmark\addition_json\01112_O_E_N_C5.json
# Processing file: D:\human_fall\re_landmark\addition_json\01112_O_E_N_C6.json
# Processing file: D:\human_fall\re_landmark\addition_json\01112_O_E_N_C7.json
# Processing file: D:\human_fall\re_landmark\addition_json\01112_O_E_N_C8.json
# Processing file: D:\human_fall\re_landmark\addition_json\01128_O_E_N_C1.json
# Processing file: D:\human_fall\re_landmark\addition_json\01128_O_E_N_C2.json
# Processing file: D:\human_fall\re_landmark\addition_json\01128_O_E_N_C3.json
# Processing file: D:\human_fall\re_landmark\addition_json\01128_O_E_N_C4.json
# Processing file: D:\human_fall\re_landmark\addition_json\01128_O_E_N_C5.json
# Processing file: D:\human_fall\re_landmark\addition_json\01128_O_E_N_C6.json
# Processing file: D:\human_fall\re_landmark\addition_json\01128_O_E_N_C7.json
# Processing file: D:\human_fall\re_landmark\addition_json\01128_O_E_N_C8.json
# Processing file: D:\human_fall\re_landmark\addition_json\01130_O_E_BY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_json\01130_O_E_BY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_json\01130_O_E_BY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_json\01130_O_E_BY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_json\01130_O_E_BY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_json\01130_O_E_BY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_json\01130_O_E_BY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_json\01130_O_E_BY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_json\01135_O_E_N_C1.json
# Processing file: D:\human_fall\re_landmark\addition_json\01135_O_E_N_C2.json
# Processing file: D:\human_fall\re_landmark\addition_json\01135_O_E_N_C3.json
# Processing file: D:\human_fall\re_landmark\addition_json\01135_O_E_N_C4.json
# Processing file: D:\human_fall\re_landmark\addition_json\01135_O_E_N_C5.json
# Processing file: D:\human_fall\re_landmark\addition_json\01135_O_E_N_C6.json
# Processing file: D:\human_fall\re_landmark\addition_json\01135_O_E_N_C7.json
# Processing file: D:\human_fall\re_landmark\addition_json\01135_O_E_N_C8.json
# Processing file: D:\human_fall\re_landmark\addition_json\01148_O_E_N_C1.json
# Processing file: D:\human_fall\re_landmark\addition_json\01148_O_E_N_C2.json
# Processing file: D:\human_fall\re_landmark\addition_json\01148_O_E_N_C3.json
# Processing file: D:\human_fall\re_landmark\addition_json\01148_O_E_N_C4.json
# Processing file: D:\human_fall\re_landmark\addition_json\01148_O_E_N_C5.json
# Processing file: D:\human_fall\re_landmark\addition_json\01148_O_E_N_C6.json
# Processing file: D:\human_fall\re_landmark\addition_json\01148_O_E_N_C7.json
# Processing file: D:\human_fall\re_landmark\addition_json\01148_O_E_N_C8.json
# Processing file: D:\human_fall\re_landmark\addition_json\01162_O_E_N_C1.json
# Processing file: D:\human_fall\re_landmark\addition_json\01162_O_E_N_C2.json
# Processing file: D:\human_fall\re_landmark\addition_json\01162_O_E_N_C3.json
# Processing file: D:\human_fall\re_landmark\addition_json\01162_O_E_N_C4.json
# Processing file: D:\human_fall\re_landmark\addition_json\01162_O_E_N_C5.json
# Processing file: D:\human_fall\re_landmark\addition_json\01162_O_E_N_C6.json
# Processing file: D:\human_fall\re_landmark\addition_json\01162_O_E_N_C7.json
# Processing file: D:\human_fall\re_landmark\addition_json\01162_O_E_N_C8.json
# Processing file: D:\human_fall\re_landmark\addition_json\01164_O_E_FY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_json\01164_O_E_FY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_json\01164_O_E_FY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_json\01164_O_E_FY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_json\01164_O_E_FY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_json\01164_O_E_FY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_json\01164_O_E_FY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_json\01164_O_E_FY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_json\01198_O_E_N_C1.json
# Processing file: D:\human_fall\re_landmark\addition_json\01198_O_E_N_C2.json
# Processing file: D:\human_fall\re_landmark\addition_json\01198_O_E_N_C3.json
# Processing file: D:\human_fall\re_landmark\addition_json\01198_O_E_N_C4.json
# Processing file: D:\human_fall\re_landmark\addition_json\01198_O_E_N_C5.json
# Processing file: D:\human_fall\re_landmark\addition_json\01198_O_E_N_C6.json
# Processing file: D:\human_fall\re_landmark\addition_json\01198_O_E_N_C7.json
# Processing file: D:\human_fall\re_landmark\addition_json\01198_O_E_N_C8.json
# Processing file: D:\human_fall\re_landmark\addition_json\01223_O_E_BY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_json\01223_O_E_BY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_json\01223_O_E_BY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_json\01223_O_E_BY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_json\01223_O_E_BY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_json\01223_O_E_BY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_json\01223_O_E_BY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_json\01223_O_E_BY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_json\01224_O_E_N_C1.json
# ...
# Processing file: D:\human_fall\re_landmark\addition_json\02735_H_A_FY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_json\02735_H_A_FY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_json\02735_H_A_FY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_json\02735_H_A_FY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_json\02735_H_A_FY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_json\02735_H_A_FY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_json\02735_H_A_FY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_json\02742_H_A_FY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_json\02742_H_A_FY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_json\02742_H_A_FY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_json\02742_H_A_FY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_json\02742_H_A_FY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_json\02742_H_A_FY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_json\02742_H_A_FY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_json\02742_H_A_FY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_json\02786_H_A_FY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_json\02786_H_A_FY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_json\02786_H_A_FY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_json\02786_H_A_FY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_json\02786_H_A_FY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_json\02786_H_A_FY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_json\02786_H_A_FY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_json\02786_H_A_FY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_json\02805_H_D_FY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_json\02805_H_D_FY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_json\02805_H_D_FY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_json\02805_H_D_FY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_json\02805_H_D_FY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_json\02805_H_D_FY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_json\02805_H_D_FY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_json\02805_H_D_FY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_json\02813_H_D_FY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_json\02813_H_D_FY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_json\02813_H_D_FY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_json\02813_H_D_FY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_json\02813_H_D_FY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_json\02813_H_D_FY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_json\02813_H_D_FY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_json\02813_H_D_FY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_json\02821_H_D_FY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_json\02821_H_D_FY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_json\02821_H_D_FY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_json\02821_H_D_FY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_json\02821_H_D_FY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_json\02821_H_D_FY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_json\02821_H_D_FY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_json\02821_H_D_FY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_json\02830_H_D_FY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_json\02830_H_D_FY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_json\02830_H_D_FY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_json\02830_H_D_FY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_json\02830_H_D_FY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_json\02830_H_D_FY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_json\02830_H_D_FY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_json\02830_H_D_FY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_json\02844_H_D_FY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_json\02844_H_D_FY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_json\02844_H_D_FY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_json\02844_H_D_FY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_json\02844_H_D_FY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_json\02844_H_D_FY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_json\02844_H_D_FY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_json\02844_H_D_FY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_json\02871_H_C_BY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_json\02871_H_C_BY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_json\02871_H_C_BY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_json\02871_H_C_BY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_json\02871_H_C_BY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_json\02871_H_C_BY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_json\02871_H_C_BY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_json\02871_H_C_BY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_json\02874_H_C_FY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_json\02874_H_C_FY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_json\02874_H_C_FY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_json\02874_H_C_FY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_json\02874_H_C_FY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_json\02874_H_C_FY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_json\02874_H_C_FY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_json\02874_H_C_FY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_json\02879_H_C_BY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_json\02879_H_C_BY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_json\02879_H_C_BY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_json\02879_H_C_BY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_json\02879_H_C_BY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_json\02879_H_C_BY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_json\02879_H_C_BY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_json\02879_H_C_BY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_json\02900_Y_C_BY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_json\02900_Y_C_BY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_json\02900_Y_C_BY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_json\02900_Y_C_BY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_json\02900_Y_C_BY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_json\02900_Y_C_BY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_json\02900_Y_C_BY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_json\02900_Y_C_BY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_json\02961_L_F_FY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_json\02961_L_F_FY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_json\02961_L_F_FY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_json\02961_L_F_FY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_json\02961_L_F_FY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_json\02961_L_F_FY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_json\02961_L_F_FY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_json\02961_L_F_FY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_json\02966_L_F_BY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_json\02966_L_F_BY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_json\02966_L_F_BY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_json\02966_L_F_BY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_json\02966_L_F_BY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_json\02966_L_F_BY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_json\02966_L_F_BY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_json\02966_L_F_BY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_json\02969_L_F_FY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_json\02969_L_F_FY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_json\02969_L_F_FY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_json\02969_L_F_FY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_json\02969_L_F_FY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_json\02969_L_F_FY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_json\02969_L_F_FY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_json\02969_L_F_FY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_json\02970_L_F_FY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_json\02970_L_F_FY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_json\02970_L_F_FY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_json\02970_L_F_FY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_json\02970_L_F_FY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_json\02970_L_F_FY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_json\02970_L_F_FY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_json\02970_L_F_FY_C8.json
# sequence shape: (3, 22)
# input_size : {22}
# c:\Users\user\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\optim\lr_scheduler.py:28: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn("The verbose parameter is deprecated. Please use get_last_lr() "
# Epoch [1/500], Train Loss: 0.6247, Val Loss: 0.5111
# Epoch [2/500], Train Loss: 0.5188, Val Loss: 0.4659
# Epoch [3/500], Train Loss: 0.4897, Val Loss: 0.4574
# Epoch [4/500], Train Loss: 0.4759, Val Loss: 0.4505
# Epoch [5/500], Train Loss: 0.4655, Val Loss: 0.4248
# Epoch [6/500], Train Loss: 0.4531, Val Loss: 0.4170
# Epoch [7/500], Train Loss: 0.4441, Val Loss: 0.4104
# Epoch [8/500], Train Loss: 0.4347, Val Loss: 0.4122
# Epoch [9/500], Train Loss: 0.4297, Val Loss: 0.4121
# Epoch [10/500], Train Loss: 0.4253, Val Loss: 0.3973
# Epoch [11/500], Train Loss: 0.4151, Val Loss: 0.3953
# Epoch [12/500], Train Loss: 0.4120, Val Loss: 0.3825
# Epoch [13/500], Train Loss: 0.4025, Val Loss: 0.3885
# Epoch [14/500], Train Loss: 0.4001, Val Loss: 0.3823
# Epoch [15/500], Train Loss: 0.3964, Val Loss: 0.3800
# Epoch [16/500], Train Loss: 0.3921, Val Loss: 0.3758
# Epoch [17/500], Train Loss: 0.3886, Val Loss: 0.3712
# Epoch [18/500], Train Loss: 0.3826, Val Loss: 0.3686
# Epoch [19/500], Train Loss: 0.3822, Val Loss: 0.3793
# Epoch [20/500], Train Loss: 0.3774, Val Loss: 0.3679
# Epoch [21/500], Train Loss: 0.3741, Val Loss: 0.3667
# Epoch [22/500], Train Loss: 0.3721, Val Loss: 0.3655
# Epoch [23/500], Train Loss: 0.3665, Val Loss: 0.3732
# Epoch [24/500], Train Loss: 0.3647, Val Loss: 0.3562
# Epoch [25/500], Train Loss: 0.3606, Val Loss: 0.3593
# Epoch [26/500], Train Loss: 0.3584, Val Loss: 0.3531
# Epoch [27/500], Train Loss: 0.3564, Val Loss: 0.3579
# Epoch [28/500], Train Loss: 0.3522, Val Loss: 0.3504
# Epoch [29/500], Train Loss: 0.3511, Val Loss: 0.3655
# Epoch [30/500], Train Loss: 0.3466, Val Loss: 0.3521
# Epoch [31/500], Train Loss: 0.3442, Val Loss: 0.3490
# Epoch [32/500], Train Loss: 0.3416, Val Loss: 0.3457
# Epoch [33/500], Train Loss: 0.3364, Val Loss: 0.3470
# Epoch [34/500], Train Loss: 0.3338, Val Loss: 0.3387
# Epoch [35/500], Train Loss: 0.3326, Val Loss: 0.3395
# Epoch [36/500], Train Loss: 0.3308, Val Loss: 0.3529
# Epoch [37/500], Train Loss: 0.3297, Val Loss: 0.3374
# Epoch [38/500], Train Loss: 0.3256, Val Loss: 0.3383
# Epoch [39/500], Train Loss: 0.3216, Val Loss: 0.3511
# Epoch [40/500], Train Loss: 0.3210, Val Loss: 0.3449
# Epoch [41/500], Train Loss: 0.3202, Val Loss: 0.3408
# Epoch [42/500], Train Loss: 0.3197, Val Loss: 0.3346
# Epoch [43/500], Train Loss: 0.3141, Val Loss: 0.3473
# Epoch [44/500], Train Loss: 0.3153, Val Loss: 0.3470
# Epoch [45/500], Train Loss: 0.3111, Val Loss: 0.3551
# Epoch [46/500], Train Loss: 0.3119, Val Loss: 0.3534
# Epoch [47/500], Train Loss: 0.3037, Val Loss: 0.3393
# Epoch [48/500], Train Loss: 0.3017, Val Loss: 0.3433
# Epoch [49/500], Train Loss: 0.2770, Val Loss: 0.3291
# Epoch [50/500], Train Loss: 0.2706, Val Loss: 0.3323
# Epoch [51/500], Train Loss: 0.2660, Val Loss: 0.3370
# Epoch [52/500], Train Loss: 0.2654, Val Loss: 0.3348
# Epoch [53/500], Train Loss: 0.2664, Val Loss: 0.3303
# Epoch [54/500], Train Loss: 0.2654, Val Loss: 0.3303
# Epoch [55/500], Train Loss: 0.2644, Val Loss: 0.3282
# Epoch [56/500], Train Loss: 0.2631, Val Loss: 0.3305
# Epoch [57/500], Train Loss: 0.2582, Val Loss: 0.3328
# Epoch [58/500], Train Loss: 0.2624, Val Loss: 0.3327
# Epoch [59/500], Train Loss: 0.2600, Val Loss: 0.3311
# Epoch [60/500], Train Loss: 0.2603, Val Loss: 0.3358
# Epoch [61/500], Train Loss: 0.2599, Val Loss: 0.3344
# Epoch [62/500], Train Loss: 0.2561, Val Loss: 0.3342
# Epoch [63/500], Train Loss: 0.2549, Val Loss: 0.3336
# Epoch [64/500], Train Loss: 0.2573, Val Loss: 0.3326
# Epoch [65/500], Train Loss: 0.2539, Val Loss: 0.3326
# Epoch [66/500], Train Loss: 0.2539, Val Loss: 0.3337
# Epoch [67/500], Train Loss: 0.2522, Val Loss: 0.3343
# Epoch [68/500], Train Loss: 0.2524, Val Loss: 0.3343
# Epoch [69/500], Train Loss: 0.2524, Val Loss: 0.3343
# Epoch [70/500], Train Loss: 0.2544, Val Loss: 0.3341
# Epoch [71/500], Train Loss: 0.2558, Val Loss: 0.3340
# Epoch [72/500], Train Loss: 0.2547, Val Loss: 0.3340
# Epoch [73/500], Train Loss: 0.2541, Val Loss: 0.3340
# Epoch [74/500], Train Loss: 0.2538, Val Loss: 0.3340
# Epoch [75/500], Train Loss: 0.2563, Val Loss: 0.3340
# Epoch [76/500], Train Loss: 0.2558, Val Loss: 0.3340
# Epoch [77/500], Train Loss: 0.2543, Val Loss: 0.3339
# Epoch [78/500], Train Loss: 0.2551, Val Loss: 0.3339
# Epoch [79/500], Train Loss: 0.2548, Val Loss: 0.3339
# Epoch [80/500], Train Loss: 0.2519, Val Loss: 0.3339
# Epoch [81/500], Train Loss: 0.2537, Val Loss: 0.3339
# Epoch [82/500], Train Loss: 0.2539, Val Loss: 0.3339
# Epoch [83/500], Train Loss: 0.2522, Val Loss: 0.3339
# Epoch [84/500], Train Loss: 0.2560, Val Loss: 0.3339
# Epoch [85/500], Train Loss: 0.2529, Val Loss: 0.3339
# Epoch [86/500], Train Loss: 0.2526, Val Loss: 0.3339
# Epoch [87/500], Train Loss: 0.2569, Val Loss: 0.3339
# Epoch [88/500], Train Loss: 0.2536, Val Loss: 0.3339
# Epoch [89/500], Train Loss: 0.2536, Val Loss: 0.3339
# Epoch [90/500], Train Loss: 0.2573, Val Loss: 0.3339
# Epoch [91/500], Train Loss: 0.2511, Val Loss: 0.3339
# Epoch [92/500], Train Loss: 0.2551, Val Loss: 0.3339
# Epoch [93/500], Train Loss: 0.2531, Val Loss: 0.3339
# Epoch [94/500], Train Loss: 0.2548, Val Loss: 0.3339
# Epoch [95/500], Train Loss: 0.2541, Val Loss: 0.3339
# Epoch [96/500], Train Loss: 0.2542, Val Loss: 0.3339
# Epoch [97/500], Train Loss: 0.2550, Val Loss: 0.3339
# Epoch [98/500], Train Loss: 0.2529, Val Loss: 0.3339
# Epoch [99/500], Train Loss: 0.2547, Val Loss: 0.3339
# Epoch [100/500], Train Loss: 0.2539, Val Loss: 0.3339
# Epoch [101/500], Train Loss: 0.2524, Val Loss: 0.3339
# Epoch [102/500], Train Loss: 0.2549, Val Loss: 0.3339
# Epoch [103/500], Train Loss: 0.2535, Val Loss: 0.3339
# Epoch [104/500], Train Loss: 0.2534, Val Loss: 0.3339
# Epoch [105/500], Train Loss: 0.2539, Val Loss: 0.3339
# Early stopping
# Train F1: 0.9304, Val F1: 0.9126
# Train CM:
# [[42935  2803  1191]
#  [  469  6088   280]
#  [  410   870 26986]]
# Val CM:
# [[10458   724   361]
#  [  227  1428   141]
#  [  141   282  6746]]
# 학습 완료

# %% [markdown]
# ### sensordata와 yolo bbox 좌표를 동시에 training
# * 클래스 예측은 랜드마크의 좌표값을 우선적으로, 차선으로 bbox 좌표로 분류하도록 수정

# %%
LANDMARKS = [0, 11, 12, 15, 16, 23, 24, 25, 26, 27, 28]

# bbox의 비율 계산 함수
def bbox_ratio(bbox) : 
    w = bbox['x2'] - bbox['x1']
    h = bbox['y2'] - bbox['y1']
    return w / h if w != 0 else 0

# bbox의 비율에 따른 클래스 분류 
def bbox_ratio_class(ratio) :
    if ratio < 0.5 : 
        return 0 # Normal 클래스
    elif 0.5 < ratio < 0.7 : 
        return 1 # Danger 클래스
    else : 
        return 2 # Fall 클래스 
    
# 데이터셋 클래스 정의
class FallSequenceDataset(Dataset):
    def __init__(self, json_files, sequence_length=3):
        self.sequence_length = sequence_length
        self.sequences = []
        self.labels = []
        self.scaler = StandardScaler()
        print(f"LANDMARKS length: {len(LANDMARKS)}")
           
        all_landmarks = []
        
        for json_file in json_files:
            print(f'Processing file: {json_file}')
            with open(json_file, 'r') as f:
                data = json.load(f)
            
            frames = list(data['pose_data'].values())
            
            for i in range(0, len(frames) - self.sequence_length + 1):
                sequence = frames[i:i+self.sequence_length]
                landmarks = []
                
                for frame in sequence:
                    frame_landmarks = []
                    for landmark in LANDMARKS:
                        frame_landmarks.extend([
                            frame[f'landmark_{landmark}']['x'],
                            frame[f'landmark_{landmark}']['y']
                        ])
                        
                    # YOLO bbox 좌표 추가
                    try:
                        bbox = frame['bbox']
                        frame_landmarks.extend([
                            frame['bbox']['x1'],
                            frame['bbox']['y1'],
                            frame['bbox']['x2'],
                            frame['bbox']['y2']
                        ])
                        
                        # bbox 비율에 따른 클래스 결정
                        b_ratio = bbox_ratio(bbox)
                        label = bbox_ratio_class(b_ratio)
                        
                    except KeyError:
                        print('bbox 정보 없음. 기본값으로 사용')
                        frame_landmarks.extend([0, 0, 1, 1])  # 기본값 사용
                        
                    landmarks.append(frame_landmarks)
                
                all_landmarks.extend(landmarks)
                
                # 마지막 프레임의 클래스를 레이블로 사용
                label = 0 if frame['class'] == 'Normal' else (1 if frame['class'] == 'Danger' else 2)
                
                self.sequences.append(landmarks)
                self.labels.append(label)
        
        # 전체 데이터 정규화
        all_landmarks = np.array(all_landmarks)
        all_landmarks_scaled = self.scaler.fit_transform(all_landmarks)
        
        # 정규화된 데이터를 다시 시퀀스로 재구성
        for i in range(len(self.sequences)):
            start = i * self.sequence_length
            end = start + self.sequence_length
            self.sequences[i] = all_landmarks_scaled[start:end]
        
        if self.sequences:
            print(f"sequence shape: {self.sequences[0].shape}")
            print(f"Features per frame: {self.sequences[0].shape[1]}")
        else:
            print("sequences 생성 실패")

    def __len__(self):
        return len(self.sequences)

    def __getitem__(self, idx):
        if idx >= len(self.sequences):
            raise IndexError(f"Index {idx} out of range. Dataset length: {len(self.sequences)}")
        sequence = self.sequences[idx]
        return torch.FloatTensor(sequence), torch.LongTensor([self.labels[idx]]).squeeze()

# GRU 모델 정의
class FallDetectionGRU(nn.Module):
    def __init__(self, input_size, hidden_size=64, num_layers=2, output_size=3, dropout=0.5):
        super(FallDetectionGRU, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.gru = nn.GRU(input_size, hidden_size, num_layers, batch_first=True, dropout=dropout)
        self.fc = nn.Linear(hidden_size, output_size)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(x.device)
        out, _ = self.gru(x, h0)
        out = self.dropout(out[:, -1, :])
        out = self.fc(out)
        return out

# 데이터 로드 및 전처리
json_folder = 'D:\\human_fall\\re_landmark\\addition_yolobbox_json'
json_files = [os.path.join(json_folder, f) for f in os.listdir(json_folder) if f.endswith('.json')]
dataset = FallSequenceDataset(json_files)

# 데이터셋을 학습 및 검증 세트로 분할
train_indices, val_indices = train_test_split(range(len(dataset)), test_size=0.2)
train_dataset = torch.utils.data.Subset(dataset, train_indices)
val_dataset = torch.utils.data.Subset(dataset, val_indices)

# 데이터 로더 생성 전에 클래스 가중치 계산
class_weights = compute_class_weight('balanced', classes=np.unique(dataset.labels), y=dataset.labels)
class_weights = torch.FloatTensor(class_weights).to(device)

# 손실 함수에 가중치 적용
criterion = nn.CrossEntropyLoss(weight=class_weights)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=32)

if len(dataset) > 0:
    sample_sequence, sample_label = dataset[0]
    input_size = sample_sequence.shape[1]
    print(f'input_size : {input_size}')
    model = FallDetectionGRU(input_size).to(device)
else:
    print("데이터 없음")
    exit()

optimizer = torch.optim.Adam(model.parameters(), lr=0.001, weight_decay=1e-5)
scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=5, verbose=True)
num_epochs = 500
best_loss = float('inf')
patience = 50
no_improve = 0

for epoch in range(num_epochs):
    model.train()
    total_loss_train = 0
    
    for sequences, labels in train_loader:
        sequences, labels = sequences.to(device), labels.to(device)
        
        optimizer.zero_grad()
        outputs = model(sequences)
        loss_train = criterion(outputs, labels.view(-1))
        loss_train.backward()
        optimizer.step()
        
        total_loss_train += loss_train.item()
    
    avg_loss_train = total_loss_train / len(train_loader)

    # 검증 단계
    model.eval()
    total_loss_val = 0
    
    with torch.no_grad():
        for sequences_val, labels_val in val_loader:
            sequences_val, labels_val = sequences_val.to(device), labels_val.to(device)
            outputs_val = model(sequences_val)
            loss_val = criterion(outputs_val, labels_val.view(-1))
            total_loss_val += loss_val.item()
    
    avg_loss_val = total_loss_val / len(val_loader)

    print(f'Epoch [{epoch+1}/{num_epochs}], Train Loss: {avg_loss_train:.4f}, Val Loss: {avg_loss_val:.4f}')
    scheduler.step(avg_loss_val)
    
    if avg_loss_val < best_loss:
        best_loss = avg_loss_val
        no_improve = 0
        torch.save(model.state_dict(), 'add_sensordata_bbox.pt')
    else:
        no_improve += 1
    
    if no_improve >= patience:
        print("Early stopping")
        break

def calculate_metrics(model, data_loader):
    model.eval()
    all_preds = []
    all_labels = []
    with torch.no_grad():
        for sequences, labels in data_loader:
            sequences, labels = sequences.to(device), labels.to(device)
            outputs = model(sequences)
            _, preds = torch.max(outputs, 1)
            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())
    
    f1 = f1_score(all_labels, all_preds, average='weighted')
    cm = confusion_matrix(all_labels, all_preds)
    return f1, cm

# 학습 루프 내에서 성능 지표 계산
train_f1, train_cm = calculate_metrics(model, train_loader)
val_f1, val_cm = calculate_metrics(model, val_loader)
print(f'Train F1: {train_f1:.4f}, Val F1: {val_f1:.4f}')
print(f'Train CM:\n{train_cm}\nVal CM:\n{val_cm}')

print("학습 완료")
# Out:
# LANDMARKS length: 11
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00060_H_A_SY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00060_H_A_SY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00060_H_A_SY_C3.json
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00060_H_A_SY_C4.json
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00060_H_A_SY_C5.json
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00060_H_A_SY_C6.json
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00060_H_A_SY_C7.json
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00060_H_A_SY_C8.json
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00093_H_A_FY_C1.json
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00093_H_A_FY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00093_H_A_FY_C3.json
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00093_H_A_FY_C4.json
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00093_H_A_FY_C5.json
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00093_H_A_FY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00093_H_A_FY_C7.json
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00093_H_A_FY_C8.json
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00096_H_A_FY_C1.json
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00096_H_A_FY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00096_H_A_FY_C3.json
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00096_H_A_FY_C4.json
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00096_H_A_FY_C5.json
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00096_H_A_FY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00096_H_A_FY_C7.json
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00096_H_A_FY_C8.json
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00108_H_A_SY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00108_H_A_SY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00108_H_A_SY_C3.json
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00108_H_A_SY_C4.json
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00108_H_A_SY_C5.json
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00108_H_A_SY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00108_H_A_SY_C7.json
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00108_H_A_SY_C8.json
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00112_H_A_SY_C1.json
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00112_H_A_SY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00112_H_A_SY_C3.json
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00112_H_A_SY_C4.json
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00112_H_A_SY_C5.json
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00112_H_A_SY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00112_H_A_SY_C7.json
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00112_H_A_SY_C8.json
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00114_H_A_BY_C1.json
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00114_H_A_BY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00114_H_A_BY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00114_H_A_BY_C4.json
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00114_H_A_BY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00114_H_A_BY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00114_H_A_BY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00114_H_A_BY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00121_H_A_N_C1.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00121_H_A_N_C2.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00121_H_A_N_C3.json
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00121_H_A_N_C4.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00121_H_A_N_C5.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00121_H_A_N_C6.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00121_H_A_N_C7.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00121_H_A_N_C8.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00130_H_A_FY_C1.json
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00130_H_A_FY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00130_H_A_FY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00130_H_A_FY_C4.json
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00130_H_A_FY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00130_H_A_FY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00130_H_A_FY_C7.json
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00130_H_A_FY_C8.json
# bbox 정보 없음. 기본값으로 사용
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00132_H_A_BY_C1.json
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00132_H_A_BY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00132_H_A_BY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00132_H_A_BY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00132_H_A_BY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00132_H_A_BY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00132_H_A_BY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00132_H_A_BY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00158_H_A_SY_C1.json
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00158_H_A_SY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00158_H_A_SY_C3.json
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00158_H_A_SY_C4.json
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00158_H_A_SY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00158_H_A_SY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00158_H_A_SY_C7.json
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00158_H_A_SY_C8.json
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00164_H_A_N_C1.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00164_H_A_N_C2.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00164_H_A_N_C3.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00164_H_A_N_C4.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00164_H_A_N_C5.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00164_H_A_N_C6.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00164_H_A_N_C7.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00164_H_A_N_C8.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00171_H_A_BY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00171_H_A_BY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00171_H_A_BY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00171_H_A_BY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00171_H_A_BY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00171_H_A_BY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00171_H_A_BY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00171_H_A_BY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00172_H_A_N_C1.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00172_H_A_N_C2.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00172_H_A_N_C3.json
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00172_H_A_N_C4.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00172_H_A_N_C5.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00172_H_A_N_C6.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00172_H_A_N_C7.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00172_H_A_N_C8.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00174_H_A_SY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00174_H_A_SY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00174_H_A_SY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00174_H_A_SY_C4.json
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00174_H_A_SY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00174_H_A_SY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00174_H_A_SY_C7.json
# bbox 정보 없음. 기본값으로 사용
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00174_H_A_SY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00175_H_A_BY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00175_H_A_BY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00175_H_A_BY_C3.json
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00175_H_A_BY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00175_H_A_BY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00175_H_A_BY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00175_H_A_BY_C7.json
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00175_H_A_BY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00188_H_A_N_C1.json
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00188_H_A_N_C2.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00188_H_A_N_C3.json
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00188_H_A_N_C4.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00188_H_A_N_C5.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00188_H_A_N_C6.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00188_H_A_N_C7.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00188_H_A_N_C8.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00191_H_A_BY_C1.json
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00191_H_A_BY_C2.json
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00191_H_A_BY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00191_H_A_BY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00191_H_A_BY_C5.json
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00191_H_A_BY_C6.json
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00191_H_A_BY_C7.json
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00191_H_A_BY_C8.json
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00193_H_A_FY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00193_H_A_FY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00193_H_A_FY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00193_H_A_FY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00193_H_A_FY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00193_H_A_FY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00193_H_A_FY_C7.json
# bbox 정보 없음. 기본값으로 사용
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00193_H_A_FY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00194_H_A_SY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00194_H_A_SY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00194_H_A_SY_C3.json
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00194_H_A_SY_C4.json
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00194_H_A_SY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00194_H_A_SY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00194_H_A_SY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00194_H_A_SY_C8.json
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00247_H_D_BY_C1.json
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00247_H_D_BY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00247_H_D_BY_C3.json
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00247_H_D_BY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00247_H_D_BY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00247_H_D_BY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00247_H_D_BY_C7.json
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00247_H_D_BY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00258_H_D_SY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00258_H_D_SY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00258_H_D_SY_C3.json
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00258_H_D_SY_C4.json
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00258_H_D_SY_C5.json
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00258_H_D_SY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00258_H_D_SY_C7.json
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00258_H_D_SY_C8.json
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00265_H_D_FY_C1.json
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00265_H_D_FY_C2.json
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00265_H_D_FY_C3.json
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00265_H_D_FY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00265_H_D_FY_C5.json
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00265_H_D_FY_C6.json
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00265_H_D_FY_C7.json
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00265_H_D_FY_C8.json
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\00269_H_D_FY_C1.json
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# ...
# bbox 정보 없음. 기본값으로 사용
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\02879_H_C_BY_C8.json
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\02900_Y_C_BY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\02900_Y_C_BY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\02900_Y_C_BY_C3.json
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\02900_Y_C_BY_C4.json
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\02900_Y_C_BY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\02900_Y_C_BY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\02900_Y_C_BY_C7.json
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\02900_Y_C_BY_C8.json
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\02961_L_F_FY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\02961_L_F_FY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\02961_L_F_FY_C3.json
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\02961_L_F_FY_C4.json
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\02961_L_F_FY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\02961_L_F_FY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\02961_L_F_FY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\02961_L_F_FY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\02966_L_F_BY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\02966_L_F_BY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\02966_L_F_BY_C3.json
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\02966_L_F_BY_C4.json
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\02966_L_F_BY_C5.json
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\02966_L_F_BY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\02966_L_F_BY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\02966_L_F_BY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\02969_L_F_FY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\02969_L_F_FY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\02969_L_F_FY_C3.json
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\02969_L_F_FY_C4.json
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\02969_L_F_FY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\02969_L_F_FY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\02969_L_F_FY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\02969_L_F_FY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\02970_L_F_FY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\02970_L_F_FY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\02970_L_F_FY_C3.json
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\02970_L_F_FY_C4.json
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# bbox 정보 없음. 기본값으로 사용
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\02970_L_F_FY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\02970_L_F_FY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\02970_L_F_FY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json\02970_L_F_FY_C8.json
# sequence shape: (3, 26)
# Features per frame: 26
# input_size : 26
# c:\Users\user\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\optim\lr_scheduler.py:28: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn("The verbose parameter is deprecated. Please use get_last_lr() "
# Epoch [1/500], Train Loss: 0.5996, Val Loss: 0.4709
# Epoch [2/500], Train Loss: 0.4966, Val Loss: 0.4473
# Epoch [3/500], Train Loss: 0.4559, Val Loss: 0.3990
# Epoch [4/500], Train Loss: 0.4310, Val Loss: 0.3873
# Epoch [5/500], Train Loss: 0.4142, Val Loss: 0.3707
# Epoch [6/500], Train Loss: 0.4031, Val Loss: 0.3650
# Epoch [7/500], Train Loss: 0.3913, Val Loss: 0.3582
# Epoch [8/500], Train Loss: 0.3819, Val Loss: 0.3400
# Epoch [9/500], Train Loss: 0.3723, Val Loss: 0.3343
# Epoch [10/500], Train Loss: 0.3650, Val Loss: 0.3203
# Epoch [11/500], Train Loss: 0.3564, Val Loss: 0.3342
# Epoch [12/500], Train Loss: 0.3496, Val Loss: 0.3294
# Epoch [13/500], Train Loss: 0.3419, Val Loss: 0.3298
# Epoch [14/500], Train Loss: 0.3362, Val Loss: 0.3135
# Epoch [15/500], Train Loss: 0.3342, Val Loss: 0.3096
# Epoch [16/500], Train Loss: 0.3276, Val Loss: 0.3067
# Epoch [17/500], Train Loss: 0.3205, Val Loss: 0.3042
# Epoch [18/500], Train Loss: 0.3139, Val Loss: 0.3170
# Epoch [19/500], Train Loss: 0.3097, Val Loss: 0.2959
# Epoch [20/500], Train Loss: 0.3076, Val Loss: 0.2930
# Epoch [21/500], Train Loss: 0.3016, Val Loss: 0.2996
# Epoch [22/500], Train Loss: 0.2992, Val Loss: 0.2873
# Epoch [23/500], Train Loss: 0.2954, Val Loss: 0.2914
# Epoch [24/500], Train Loss: 0.2886, Val Loss: 0.2982
# Epoch [25/500], Train Loss: 0.2869, Val Loss: 0.3036
# Epoch [26/500], Train Loss: 0.2837, Val Loss: 0.2822
# Epoch [27/500], Train Loss: 0.2746, Val Loss: 0.2874
# Epoch [28/500], Train Loss: 0.2776, Val Loss: 0.2874
# Epoch [29/500], Train Loss: 0.2715, Val Loss: 0.2800
# Epoch [30/500], Train Loss: 0.2709, Val Loss: 0.2796
# Epoch [31/500], Train Loss: 0.2658, Val Loss: 0.2772
# Epoch [32/500], Train Loss: 0.2637, Val Loss: 0.2849
# Epoch [33/500], Train Loss: 0.2654, Val Loss: 0.2799
# Epoch [34/500], Train Loss: 0.2593, Val Loss: 0.2728
# Epoch [35/500], Train Loss: 0.2578, Val Loss: 0.2815
# Epoch [36/500], Train Loss: 0.2535, Val Loss: 0.2727
# Epoch [37/500], Train Loss: 0.2524, Val Loss: 0.2742
# Epoch [38/500], Train Loss: 0.2463, Val Loss: 0.2808
# Epoch [39/500], Train Loss: 0.2450, Val Loss: 0.2802
# Epoch [40/500], Train Loss: 0.2419, Val Loss: 0.2731
# Epoch [41/500], Train Loss: 0.2419, Val Loss: 0.2789
# Epoch [42/500], Train Loss: 0.2402, Val Loss: 0.2790
# Epoch [43/500], Train Loss: 0.2140, Val Loss: 0.2701
# Epoch [44/500], Train Loss: 0.2045, Val Loss: 0.2702
# Epoch [45/500], Train Loss: 0.2000, Val Loss: 0.2716
# Epoch [46/500], Train Loss: 0.1994, Val Loss: 0.2714
# Epoch [47/500], Train Loss: 0.1957, Val Loss: 0.2753
# Epoch [48/500], Train Loss: 0.1929, Val Loss: 0.2731
# Epoch [49/500], Train Loss: 0.1947, Val Loss: 0.2755
# Epoch [50/500], Train Loss: 0.1911, Val Loss: 0.2754
# Epoch [51/500], Train Loss: 0.1889, Val Loss: 0.2760
# Epoch [52/500], Train Loss: 0.1890, Val Loss: 0.2760
# Epoch [53/500], Train Loss: 0.1888, Val Loss: 0.2762
# Epoch [54/500], Train Loss: 0.1881, Val Loss: 0.2756
# Epoch [55/500], Train Loss: 0.1908, Val Loss: 0.2760
# Epoch [56/500], Train Loss: 0.1893, Val Loss: 0.2759
# Epoch [57/500], Train Loss: 0.1869, Val Loss: 0.2760
# Epoch [58/500], Train Loss: 0.1889, Val Loss: 0.2760
# Epoch [59/500], Train Loss: 0.1886, Val Loss: 0.2760
# Epoch [60/500], Train Loss: 0.1870, Val Loss: 0.2760
# Epoch [61/500], Train Loss: 0.1905, Val Loss: 0.2760
# Epoch [62/500], Train Loss: 0.1896, Val Loss: 0.2760
# Epoch [63/500], Train Loss: 0.1880, Val Loss: 0.2760
# Epoch [64/500], Train Loss: 0.1898, Val Loss: 0.2760
# Epoch [65/500], Train Loss: 0.1878, Val Loss: 0.2760
# Epoch [66/500], Train Loss: 0.1863, Val Loss: 0.2760
# Epoch [67/500], Train Loss: 0.1866, Val Loss: 0.2760
# Epoch [68/500], Train Loss: 0.1894, Val Loss: 0.2760
# Epoch [69/500], Train Loss: 0.1886, Val Loss: 0.2760
# Epoch [70/500], Train Loss: 0.1888, Val Loss: 0.2760
# Epoch [71/500], Train Loss: 0.1873, Val Loss: 0.2760
# Epoch [72/500], Train Loss: 0.1867, Val Loss: 0.2760
# Epoch [73/500], Train Loss: 0.1881, Val Loss: 0.2760
# Epoch [74/500], Train Loss: 0.1866, Val Loss: 0.2760
# Epoch [75/500], Train Loss: 0.1885, Val Loss: 0.2760
# Epoch [76/500], Train Loss: 0.1892, Val Loss: 0.2760
# Epoch [77/500], Train Loss: 0.1896, Val Loss: 0.2760
# Epoch [78/500], Train Loss: 0.1882, Val Loss: 0.2760
# Epoch [79/500], Train Loss: 0.1879, Val Loss: 0.2760
# Epoch [80/500], Train Loss: 0.1900, Val Loss: 0.2760
# Epoch [81/500], Train Loss: 0.1891, Val Loss: 0.2760
# Epoch [82/500], Train Loss: 0.1885, Val Loss: 0.2760
# Epoch [83/500], Train Loss: 0.1880, Val Loss: 0.2760
# Epoch [84/500], Train Loss: 0.1867, Val Loss: 0.2760
# Epoch [85/500], Train Loss: 0.1923, Val Loss: 0.2760
# Epoch [86/500], Train Loss: 0.1879, Val Loss: 0.2760
# Epoch [87/500], Train Loss: 0.1875, Val Loss: 0.2760
# Epoch [88/500], Train Loss: 0.1902, Val Loss: 0.2760
# Epoch [89/500], Train Loss: 0.1903, Val Loss: 0.2760
# Epoch [90/500], Train Loss: 0.1886, Val Loss: 0.2759
# Epoch [91/500], Train Loss: 0.1896, Val Loss: 0.2759
# Epoch [92/500], Train Loss: 0.1881, Val Loss: 0.2759
# Epoch [93/500], Train Loss: 0.1870, Val Loss: 0.2759
# Early stopping
# Train F1: 0.9486, Val F1: 0.9306
# Train CM:
# [[43576  2445   731]
#  [  264  6489   138]
#  [  182   691 27516]]
# Val CM:
# [[10811   687   222]
#  [  160  1460   122]
#  [   91   215  6740]]
# 학습 완료
